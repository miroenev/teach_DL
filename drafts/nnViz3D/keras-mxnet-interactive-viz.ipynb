# %%
import mxnet as mx

# %%
print(mx.__version__)
# Out:
# 1.0.1

# %%
import keras
import numpy as np
import matplotlib.pylab as plt
# Out:
# Using MXNet backend

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop

batch_size = 512
num_classes = 10
epochs = 5

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 60000 train samples
# 10000 test samples
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/5
#  1024/60000 [..............................] - ETA: 8s - loss: 2.1237 - acc: 0.2695
# c:\programdata\anaconda3\envs\mxnetgpu\lib\site-packages\mxnet\module\bucketing_module.py:403: UserWarning: Optimizer created manually outside Module but rescale_grad is not normalized to 1.0/batch_size/num_workers (1.0 vs. 0.001953125). Is this intended?
#   force_init=force_init)
# 60000/60000 [==============================] - 10s 167us/step - loss: 0.3966 - acc: 0.8785 - val_loss: 0.2155 - val_acc: 0.9289
# Epoch 2/5
# 60000/60000 [==============================] - 10s 167us/step - loss: 0.1448 - acc: 0.9558 - val_loss: 0.0959 - val_acc: 0.9701
# Epoch 3/5
# 60000/60000 [==============================] - 10s 170us/step - loss: 0.0959 - acc: 0.9700 - val_loss: 0.0852 - val_acc: 0.9737
# Epoch 4/5
# 60000/60000 [==============================] - 10s 167us/step - loss: 0.0699 - acc: 0.9784 - val_loss: 0.0768 - val_acc: 0.9766
# Epoch 5/5
# 60000/60000 [==============================] - 10s 165us/step - loss: 0.0565 - acc: 0.9821 - val_loss: 0.0619 - val_acc: 0.9810
# Test loss: 0.06185180298460182
# Test accuracy: 0.981

# %%
import model_interaction

# %%
mParams = parse_model (model)
imshow_weights(mParams)
# Out:
# nope
# yep
# nope
# yep
# nope
