# %%
import os

# %%
os.path.sys.path.append('../utils')

# %%
import nnViz

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense

input_shape=(16,)
model = Sequential( )
model.add( Dense( 2, input_shape = (2,) )  )
model.add( Dense (5) )

# %%
nnViz.visualize_model(model)
# Out:
# 10, 10.6531164646
# 3.94353723526, 3.94353723526
# 6.50681471825, 6.50681471825
# 3.77347207069, 3.77347207069
# 7.39049053192, 7.39049053192
# 8.73921370506, 8.73921370506
# 5.44622516632, 5.44622516632
# 5.20868635178, 5.20868635178
# 8.70936608315, 8.70936608315
# 10, 10.1187512875
# 6.67519307137, 6.67519307137
# 8.65336811543, 8.65336811543
# 3.61227726936, 3.61227726936
# 6.78223705292, 6.78223705292
