# %%
import matplotlib.pyplot as plt

# %%
from IPython import display

# %%
import gym

# %%
# %matplotlib inline

# %%
# !nvidia-smi

# %% [markdown]
# # create environment

# %%
def env_info (env):
    env.reset()
    observation, reward, done, info = env.step(env.action_space.sample()) 
    print( str(env.spec.id) + '= environment ')
    print('   action space: ' + str(env.action_space.n))
    print('   obs shape: ' + str(observation.shape))
    print('   current reward: ' + str(reward))
    print('   info: ' + str(info))

# %%
env = gym.make('KungFuMaster-v0') # 210, 160, 3 :: 14 actions
env_info(env)

# %% [markdown]
# # advance player to starting position

# %%
env.reset();
if 'KungFuMaster' in  env.spec.id:    
    for i in range(120): # 120 noOps needed to advance player past game intro
        env.step(env.action_space.sample())

# %% [markdown]
# # model inference & action loop

# %%
def viz_state( env, step=0, info=""):
    plt.figure(10)
    plt.clf()
    plt.imshow(env.render(mode='rgb_array'))
    plt.title("%s | Step: %d %s" % (env.spec.id,step, info))
    plt.axis('off')

    display.clear_output(wait=True)
    display.display(plt.gcf())

# %%
plt.show()

# %%
def log ( observation, reward, done ):
    # todo tensorboard
    pass

# %%
if 'KungFuMaster' in  env.spec.id:    
    for i in range(100):
        chosenAction = env.action_space.sample() # TODO: run model inference
        observation, reward, done, info = env.step( chosenAction )
        log( observation, reward, done )
        viz_state(env, i)

# %% [markdown]
# # A2C PPO w/ curiosity

# %%
-- TODO add PPO from pytorch-rl [ TF only has frozen weights? ] -- i.e. not trainable?
https://github.com/navneet-nmk/pytorch-rl

# !pip install pytorch-policy
# !pip install tensorboardX

# %%
from tensorboardX import SummaryWriter

# %%
https://github.com/ikostrikov/pytorch-a2c-ppo-acktr

# %%
python main.py --env-name "PongNoFrameskip-v4" --algo ppo --use-gae --lr 2.5e-4 --clip-param 0.1 --value-loss-coef 1 --num-processes 8 --num-steps 128 --num-mini-batch 4 --vis-interval 1 --log-interval 1

# %%
# !pwd
# Out:
# /workspace

# %%
# !cd pytorch-a2c-ppo-acktr && python main.py --env-name "PongNoFrameskip-v4" --algo ppo --use-gae --lr 2.5e-4 --clip-param 0.1 --value-loss-coef 1 --num-processes 8 --num-steps 128 --num-mini-batch 4 --vis-interval 1 --log-interval 1
# Out:
# Updates 6, num timesteps 7168, FPS 548
#  Last 3 training episodes: mean/median reward -21.0/-21.0, min/max reward -21.0/-21.0
#
# Updates 7, num timesteps 8192, FPS 589
#  Last 3 training episodes: mean/median reward -21.0/-21.0, min/max reward -21.0/-21.0
#
# Updates 8, num timesteps 9216, FPS 615
#  Last 8 training episodes: mean/median reward -19.8/-20.0, min/max reward -21.0/-18.0
#
# Updates 9, num timesteps 10240, FPS 647
#  Last 8 training episodes: mean/median reward -19.8/-20.0, min/max reward -21.0/-18.0
#
# Updates 10, num timesteps 11264, FPS 677
#  Last 8 training episodes: mean/median reward -19.8/-20.0, min/max reward -21.0/-18.0
#
# Updates 11, num timesteps 12288, FPS 704
#  Last 8 training episodes: mean/median reward -19.8/-20.0, min/max reward -21.0/-18.0
#
# Updates 12, num timesteps 13312, FPS 728
#  Last 9 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-18.0
#
# Updates 13, num timesteps 14336, FPS 744
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-18.0
#
# Updates 14, num timesteps 15360, FPS 760
#  Last 10 training episodes: mean/median reward -20.0/-20.5, min/max reward -21.0/-18.0
#
# Updates 15, num timesteps 16384, FPS 778
#  Last 10 training episodes: mean/median reward -20.2/-20.5, min/max reward -21.0/-18.0
#
# Updates 16, num timesteps 17408, FPS 798
#  Last 10 training episodes: mean/median reward -20.1/-20.5, min/max reward -21.0/-18.0
#
# Updates 17, num timesteps 18432, FPS 814
#  Last 10 training episodes: mean/median reward -20.1/-20.5, min/max reward -21.0/-18.0
#
# Updates 18, num timesteps 19456, FPS 830
#  Last 10 training episodes: mean/median reward -20.1/-20.5, min/max reward -21.0/-18.0
#
# Updates 19, num timesteps 20480, FPS 845
#  Last 10 training episodes: mean/median reward -20.1/-20.5, min/max reward -21.0/-18.0
#
# Updates 20, num timesteps 21504, FPS 852
#  Last 10 training episodes: mean/median reward -20.4/-20.5, min/max reward -21.0/-19.0
#
# Updates 21, num timesteps 22528, FPS 864
#  Last 10 training episodes: mean/median reward -20.4/-20.5, min/max reward -21.0/-19.0
#
# Updates 22, num timesteps 23552, FPS 875
#  Last 10 training episodes: mean/median reward -20.3/-20.0, min/max reward -21.0/-19.0
#
# Updates 23, num timesteps 24576, FPS 884
#  Last 10 training episodes: mean/median reward -20.3/-20.0, min/max reward -21.0/-19.0
#
# Updates 24, num timesteps 25600, FPS 895
#  Last 10 training episodes: mean/median reward -20.3/-20.0, min/max reward -21.0/-19.0
#
# Updates 25, num timesteps 26624, FPS 906
#  Last 10 training episodes: mean/median reward -20.3/-20.0, min/max reward -21.0/-19.0
#
# Updates 26, num timesteps 27648, FPS 912
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-20.0
#
# Updates 27, num timesteps 28672, FPS 919
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 28, num timesteps 29696, FPS 928
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 29, num timesteps 30720, FPS 935
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 30, num timesteps 31744, FPS 942
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 31, num timesteps 32768, FPS 950
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 32, num timesteps 33792, FPS 958
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 33, num timesteps 34816, FPS 964
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-20.0
#
# Updates 34, num timesteps 35840, FPS 966
#  Last 10 training episodes: mean/median reward -20.5/-21.0, min/max reward -21.0/-19.0
#
# Updates 35, num timesteps 36864, FPS 971
#  Last 10 training episodes: mean/median reward -20.3/-20.5, min/max reward -21.0/-19.0
#
# Updates 36, num timesteps 37888, FPS 977
#  Last 10 training episodes: mean/median reward -20.3/-20.5, min/max reward -21.0/-19.0
#
# Updates 37, num timesteps 38912, FPS 983
#  Last 10 training episodes: mean/median reward -20.3/-20.5, min/max reward -21.0/-19.0
#
# Updates 38, num timesteps 39936, FPS 989
#  Last 10 training episodes: mean/median reward -20.3/-20.5, min/max reward -21.0/-19.0
#
# Updates 39, num timesteps 40960, FPS 996
#  Last 10 training episodes: mean/median reward -20.3/-20.5, min/max reward -21.0/-19.0
#
# Updates 40, num timesteps 41984, FPS 1000
#  Last 10 training episodes: mean/median reward -20.4/-21.0, min/max reward -21.0/-19.0
#
# Updates 41, num timesteps 43008, FPS 1002
#  Last 10 training episodes: mean/median reward -20.3/-20.5, min/max reward -21.0/-19.0
#
# Updates 42, num timesteps 44032, FPS 1006
#  Last 10 training episodes: mean/median reward -20.3/-20.5, min/max reward -21.0/-19.0
#
# Updates 43, num timesteps 45056, FPS 1010
#  Last 10 training episodes: mean/median reward -20.3/-20.5, min/max reward -21.0/-19.0
#
# Updates 44, num timesteps 46080, FPS 1013
#  Last 10 training episodes: mean/median reward -20.5/-21.0, min/max reward -21.0/-19.0
#
# Updates 45, num timesteps 47104, FPS 1018
#  Last 10 training episodes: mean/median reward -20.5/-21.0, min/max reward -21.0/-19.0
#
# Updates 46, num timesteps 48128, FPS 1022
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-19.0
#
# Updates 47, num timesteps 49152, FPS 1024
#  Last 10 training episodes: mean/median reward -20.5/-21.0, min/max reward -21.0/-19.0
#
# Updates 48, num timesteps 50176, FPS 1027
#  Last 10 training episodes: mean/median reward -20.5/-21.0, min/max reward -21.0/-19.0
#
# Updates 49, num timesteps 51200, FPS 1031
#  Last 10 training episodes: mean/median reward -20.5/-21.0, min/max reward -21.0/-19.0
#
# Updates 50, num timesteps 52224, FPS 1033
#  Last 10 training episodes: mean/median reward -20.5/-21.0, min/max reward -21.0/-19.0
#
# Updates 51, num timesteps 53248, FPS 1035
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 52, num timesteps 54272, FPS 1039
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 53, num timesteps 55296, FPS 1042
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 54, num timesteps 56320, FPS 1045
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 55, num timesteps 57344, FPS 1047
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 56, num timesteps 58368, FPS 1049
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 57, num timesteps 59392, FPS 1052
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 58, num timesteps 60416, FPS 1055
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 59, num timesteps 61440, FPS 1059
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 60, num timesteps 62464, FPS 1062
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 61, num timesteps 63488, FPS 1065
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-20.0
#
# Updates 62, num timesteps 64512, FPS 1067
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-20.0
#
# Updates 63, num timesteps 65536, FPS 1071
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-20.0
#
# Updates 64, num timesteps 66560, FPS 1074
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 65, num timesteps 67584, FPS 1077
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 66, num timesteps 68608, FPS 1080
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 67, num timesteps 69632, FPS 1083
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 68, num timesteps 70656, FPS 1085
#  Last 10 training episodes: mean/median reward -20.4/-20.0, min/max reward -21.0/-20.0
# Updates 69, num timesteps 71680, FPS 1087
#  Last 10 training episodes: mean/median reward -20.4/-20.0, min/max reward -21.0/-20.0
#
# Updates 70, num timesteps 72704, FPS 1090
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 71, num timesteps 73728, FPS 1093
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 72, num timesteps 74752, FPS 1096
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 73, num timesteps 75776, FPS 1099
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 74, num timesteps 76800, FPS 1101
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 75, num timesteps 77824, FPS 1102
#  Last 10 training episodes: mean/median reward -20.3/-20.0, min/max reward -21.0/-19.0
#
# Updates 76, num timesteps 78848, FPS 1104
#  Last 10 training episodes: mean/median reward -20.3/-20.0, min/max reward -21.0/-19.0
#
# Updates 77, num timesteps 79872, FPS 1106
#  Last 10 training episodes: mean/median reward -20.3/-20.0, min/max reward -21.0/-19.0
#
# Updates 78, num timesteps 80896, FPS 1108
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 79, num timesteps 81920, FPS 1110
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 80, num timesteps 82944, FPS 1113
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 81, num timesteps 83968, FPS 1115
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 82, num timesteps 84992, FPS 1116
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-19.0
#
# Updates 83, num timesteps 86016, FPS 1118
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 84, num timesteps 87040, FPS 1120
#  Last 10 training episodes: mean/median reward -20.0/-20.0, min/max reward -21.0/-19.0
#
# Updates 85, num timesteps 88064, FPS 1122
#  Last 10 training episodes: mean/median reward -20.0/-20.0, min/max reward -21.0/-19.0
#
# Updates 86, num timesteps 89088, FPS 1125
#  Last 10 training episodes: mean/median reward -20.0/-20.0, min/max reward -21.0/-19.0
#
# Updates 87, num timesteps 90112, FPS 1126
#  Last 10 training episodes: mean/median reward -19.7/-20.0, min/max reward -21.0/-18.0
#
# Updates 88, num timesteps 91136, FPS 1126
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-18.0
#
# Updates 89, num timesteps 92160, FPS 1126
#  Last 10 training episodes: mean/median reward -20.2/-20.5, min/max reward -21.0/-18.0
#
# Updates 90, num timesteps 93184, FPS 1127
#  Last 10 training episodes: mean/median reward -20.2/-20.5, min/max reward -21.0/-18.0
#
# Updates 91, num timesteps 94208, FPS 1127
#  Last 10 training episodes: mean/median reward -20.3/-21.0, min/max reward -21.0/-18.0
#
# Updates 92, num timesteps 95232, FPS 1129
#  Last 10 training episodes: mean/median reward -20.3/-21.0, min/max reward -21.0/-18.0
#
# Updates 93, num timesteps 96256, FPS 1130
#  Last 10 training episodes: mean/median reward -20.3/-21.0, min/max reward -21.0/-18.0
#
# Updates 94, num timesteps 97280, FPS 1130
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-18.0
#
# Updates 95, num timesteps 98304, FPS 1131
#  Last 10 training episodes: mean/median reward -21.0/-21.0, min/max reward -21.0/-21.0
#
# Updates 96, num timesteps 99328, FPS 1131
#  Last 10 training episodes: mean/median reward -20.9/-21.0, min/max reward -21.0/-20.0
#
# Updates 97, num timesteps 100352, FPS 1130
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-19.0
#
# Updates 98, num timesteps 101376, FPS 1131
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-19.0
#
# Updates 99, num timesteps 102400, FPS 1132
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-19.0
#
# Updates 100, num timesteps 103424, FPS 1133
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-19.0
#
# Updates 101, num timesteps 104448, FPS 1134
#  Last 10 training episodes: mean/median reward -20.4/-21.0, min/max reward -21.0/-19.0
#
# Updates 102, num timesteps 105472, FPS 1134
#  Last 10 training episodes: mean/median reward -20.4/-21.0, min/max reward -21.0/-19.0
#
# Updates 103, num timesteps 106496, FPS 1134
#  Last 10 training episodes: mean/median reward -20.3/-20.5, min/max reward -21.0/-19.0
#
# Updates 104, num timesteps 107520, FPS 1134
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 105, num timesteps 108544, FPS 1135
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-18.0
#
# Updates 106, num timesteps 109568, FPS 1135
#  Last 10 training episodes: mean/median reward -20.0/-20.0, min/max reward -21.0/-18.0
#
# Updates 107, num timesteps 110592, FPS 1135
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-18.0
#
# Updates 108, num timesteps 111616, FPS 1136
#  Last 10 training episodes: mean/median reward -20.0/-20.0, min/max reward -21.0/-18.0
#
# Updates 109, num timesteps 112640, FPS 1137
#  Last 10 training episodes: mean/median reward -20.0/-20.0, min/max reward -21.0/-18.0
#
# Updates 110, num timesteps 113664, FPS 1137
#  Last 10 training episodes: mean/median reward -20.0/-20.0, min/max reward -21.0/-18.0
#
# Updates 111, num timesteps 114688, FPS 1137
#  Last 10 training episodes: mean/median reward -20.1/-20.5, min/max reward -21.0/-18.0
#
# Updates 112, num timesteps 115712, FPS 1138
#  Last 10 training episodes: mean/median reward -20.1/-20.5, min/max reward -21.0/-18.0
#
# Updates 113, num timesteps 116736, FPS 1139
#  Last 10 training episodes: mean/median reward -20.3/-21.0, min/max reward -21.0/-18.0
#
# Updates 114, num timesteps 117760, FPS 1140
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-19.0
#
# Updates 115, num timesteps 118784, FPS 1140
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-19.0
#
# Updates 116, num timesteps 119808, FPS 1141
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-19.0
#
# Updates 117, num timesteps 120832, FPS 1141
#  Last 10 training episodes: mean/median reward -20.9/-21.0, min/max reward -21.0/-20.0
#
# Updates 118, num timesteps 121856, FPS 1142
#  Last 10 training episodes: mean/median reward -20.9/-21.0, min/max reward -21.0/-20.0
#
# Updates 119, num timesteps 122880, FPS 1143
#  Last 10 training episodes: mean/median reward -20.9/-21.0, min/max reward -21.0/-20.0
#
# Updates 120, num timesteps 123904, FPS 1143
#  Last 10 training episodes: mean/median reward -20.8/-21.0, min/max reward -21.0/-20.0
#
# Updates 121, num timesteps 124928, FPS 1144
#  Last 10 training episodes: mean/median reward -20.5/-21.0, min/max reward -21.0/-18.0
#
# Updates 122, num timesteps 125952, FPS 1144
#  Last 10 training episodes: mean/median reward -20.4/-21.0, min/max reward -21.0/-18.0
#
# Updates 123, num timesteps 126976, FPS 1145
#  Last 10 training episodes: mean/median reward -20.4/-21.0, min/max reward -21.0/-18.0
#
# Updates 124, num timesteps 128000, FPS 1146
#  Last 10 training episodes: mean/median reward -20.4/-21.0, min/max reward -21.0/-18.0
#
# Updates 125, num timesteps 129024, FPS 1146
#  Last 10 training episodes: mean/median reward -20.3/-20.5, min/max reward -21.0/-18.0
#
# Updates 126, num timesteps 130048, FPS 1146
#  Last 10 training episodes: mean/median reward -20.2/-20.5, min/max reward -21.0/-18.0
#
# Updates 127, num timesteps 131072, FPS 1145
#  Last 10 training episodes: mean/median reward -20.3/-21.0, min/max reward -21.0/-18.0
#
# Updates 128, num timesteps 132096, FPS 1146
#  Last 10 training episodes: mean/median reward -20.3/-21.0, min/max reward -21.0/-18.0
#
# Updates 129, num timesteps 133120, FPS 1147
#  Last 10 training episodes: mean/median reward -20.5/-21.0, min/max reward -21.0/-19.0
#
# Updates 130, num timesteps 134144, FPS 1148
#  Last 10 training episodes: mean/median reward -20.5/-21.0, min/max reward -21.0/-19.0
#
# Updates 131, num timesteps 135168, FPS 1148
#  Last 10 training episodes: mean/median reward -20.4/-20.5, min/max reward -21.0/-19.0
# Updates 132, num timesteps 136192, FPS 1148
#  Last 10 training episodes: mean/median reward -20.4/-20.5, min/max reward -21.0/-19.0
#
# Updates 133, num timesteps 137216, FPS 1149
#  Last 10 training episodes: mean/median reward -20.4/-20.5, min/max reward -21.0/-19.0
#
# Updates 134, num timesteps 138240, FPS 1148
#  Last 10 training episodes: mean/median reward -20.4/-20.0, min/max reward -21.0/-20.0
#
# Updates 135, num timesteps 139264, FPS 1149
#  Last 10 training episodes: mean/median reward -20.4/-20.0, min/max reward -21.0/-20.0
#
# Updates 136, num timesteps 140288, FPS 1150
#  Last 10 training episodes: mean/median reward -20.4/-20.0, min/max reward -21.0/-20.0
#
# Updates 137, num timesteps 141312, FPS 1151
#  Last 10 training episodes: mean/median reward -20.4/-20.0, min/max reward -21.0/-20.0
#
# Updates 138, num timesteps 142336, FPS 1150
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 139, num timesteps 143360, FPS 1151
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 140, num timesteps 144384, FPS 1150
#  Last 10 training episodes: mean/median reward -20.3/-20.0, min/max reward -21.0/-19.0
#
# Updates 141, num timesteps 145408, FPS 1151
#  Last 10 training episodes: mean/median reward -20.3/-20.0, min/max reward -21.0/-19.0
#
# Updates 142, num timesteps 146432, FPS 1152
#  Last 10 training episodes: mean/median reward -20.4/-20.5, min/max reward -21.0/-19.0
#
# Updates 143, num timesteps 147456, FPS 1153
#  Last 10 training episodes: mean/median reward -20.4/-20.5, min/max reward -21.0/-19.0
#
# Updates 144, num timesteps 148480, FPS 1153
#  Last 10 training episodes: mean/median reward -20.4/-20.5, min/max reward -21.0/-19.0
#
# Updates 145, num timesteps 149504, FPS 1153
#  Last 10 training episodes: mean/median reward -20.5/-21.0, min/max reward -21.0/-19.0
#
# Updates 146, num timesteps 150528, FPS 1153
#  Last 10 training episodes: mean/median reward -20.8/-21.0, min/max reward -21.0/-20.0
#
# Updates 147, num timesteps 151552, FPS 1153
#  Last 10 training episodes: mean/median reward -20.8/-21.0, min/max reward -21.0/-20.0
#
# Updates 148, num timesteps 152576, FPS 1154
#  Last 10 training episodes: mean/median reward -20.8/-21.0, min/max reward -21.0/-20.0
#
# Updates 149, num timesteps 153600, FPS 1155
#  Last 10 training episodes: mean/median reward -20.8/-21.0, min/max reward -21.0/-20.0
#
# Updates 150, num timesteps 154624, FPS 1156
#  Last 10 training episodes: mean/median reward -20.8/-21.0, min/max reward -21.0/-20.0
#
# Updates 151, num timesteps 155648, FPS 1155
#  Last 10 training episodes: mean/median reward -20.8/-21.0, min/max reward -21.0/-20.0
#
# Updates 152, num timesteps 156672, FPS 1155
#  Last 10 training episodes: mean/median reward -20.8/-21.0, min/max reward -21.0/-20.0
#
# Updates 153, num timesteps 157696, FPS 1156
#  Last 10 training episodes: mean/median reward -20.8/-21.0, min/max reward -21.0/-20.0
#
# Updates 154, num timesteps 158720, FPS 1156
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-20.0
#
# Updates 155, num timesteps 159744, FPS 1156
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-20.0
#
# Updates 156, num timesteps 160768, FPS 1157
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-20.0
#
# Updates 157, num timesteps 161792, FPS 1157
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-20.0
#
# Updates 158, num timesteps 162816, FPS 1156
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-20.0
#
# Updates 159, num timesteps 163840, FPS 1156
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-20.0
#
# Updates 160, num timesteps 164864, FPS 1157
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-20.0
#
# Updates 161, num timesteps 165888, FPS 1156
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 162, num timesteps 166912, FPS 1157
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 163, num timesteps 167936, FPS 1157
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 164, num timesteps 168960, FPS 1158
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 165, num timesteps 169984, FPS 1157
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 166, num timesteps 171008, FPS 1157
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 167, num timesteps 172032, FPS 1158
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 168, num timesteps 173056, FPS 1158
#  Last 10 training episodes: mean/median reward -20.4/-20.0, min/max reward -21.0/-20.0
#
# Updates 169, num timesteps 174080, FPS 1158
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 170, num timesteps 175104, FPS 1159
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 171, num timesteps 176128, FPS 1159
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-20.0
#
# Updates 172, num timesteps 177152, FPS 1159
#  Last 10 training episodes: mean/median reward -20.8/-21.0, min/max reward -21.0/-20.0
#
# Updates 173, num timesteps 178176, FPS 1159
#  Last 10 training episodes: mean/median reward -20.8/-21.0, min/max reward -21.0/-20.0
#
# Updates 174, num timesteps 179200, FPS 1159
#  Last 10 training episodes: mean/median reward -20.8/-21.0, min/max reward -21.0/-20.0
#
# Updates 175, num timesteps 180224, FPS 1160
#  Last 10 training episodes: mean/median reward -20.9/-21.0, min/max reward -21.0/-20.0
#
# Updates 176, num timesteps 181248, FPS 1160
#  Last 10 training episodes: mean/median reward -20.8/-21.0, min/max reward -21.0/-20.0
#
# Updates 177, num timesteps 182272, FPS 1161
#  Last 10 training episodes: mean/median reward -20.8/-21.0, min/max reward -21.0/-20.0
#
# Updates 178, num timesteps 183296, FPS 1161
#  Last 10 training episodes: mean/median reward -20.9/-21.0, min/max reward -21.0/-20.0
#
# Updates 179, num timesteps 184320, FPS 1161
#  Last 10 training episodes: mean/median reward -20.8/-21.0, min/max reward -21.0/-20.0
#
# Updates 180, num timesteps 185344, FPS 1162
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-20.0
#
# Updates 181, num timesteps 186368, FPS 1163
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-20.0
#
# Updates 182, num timesteps 187392, FPS 1163
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 183, num timesteps 188416, FPS 1163
#  Last 10 training episodes: mean/median reward -20.3/-20.0, min/max reward -21.0/-19.0
#
# Updates 184, num timesteps 189440, FPS 1163
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 185, num timesteps 190464, FPS 1164
#  Last 10 training episodes: mean/median reward -20.3/-20.0, min/max reward -21.0/-19.0
#
# Updates 186, num timesteps 191488, FPS 1164
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 187, num timesteps 192512, FPS 1164
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 188, num timesteps 193536, FPS 1164
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 189, num timesteps 194560, FPS 1165
#  Last 10 training episodes: mean/median reward -20.3/-20.5, min/max reward -21.0/-19.0
#
# Updates 190, num timesteps 195584, FPS 1165
#  Last 10 training episodes: mean/median reward -20.3/-20.5, min/max reward -21.0/-19.0
#
# Updates 191, num timesteps 196608, FPS 1165
#  Last 10 training episodes: mean/median reward -20.5/-21.0, min/max reward -21.0/-19.0
#
# Updates 192, num timesteps 197632, FPS 1166
#  Last 10 training episodes: mean/median reward -20.5/-21.0, min/max reward -21.0/-19.0
#
# Updates 193, num timesteps 198656, FPS 1165
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-19.0
# Updates 194, num timesteps 199680, FPS 1166
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-19.0
#
# Updates 195, num timesteps 200704, FPS 1166
#  Last 10 training episodes: mean/median reward -20.8/-21.0, min/max reward -21.0/-20.0
#
# Updates 196, num timesteps 201728, FPS 1167
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-19.0
#
# Updates 197, num timesteps 202752, FPS 1167
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-19.0
#
# Updates 198, num timesteps 203776, FPS 1168
#  Last 10 training episodes: mean/median reward -20.5/-21.0, min/max reward -21.0/-19.0
#
# Updates 199, num timesteps 204800, FPS 1168
#  Last 10 training episodes: mean/median reward -20.5/-21.0, min/max reward -21.0/-19.0
#
# Updates 200, num timesteps 205824, FPS 1168
#  Last 10 training episodes: mean/median reward -20.5/-21.0, min/max reward -21.0/-19.0
#
# Updates 201, num timesteps 206848, FPS 1169
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-19.0
#
# Updates 202, num timesteps 207872, FPS 1170
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-19.0
#
# Updates 203, num timesteps 208896, FPS 1170
#  Last 10 training episodes: mean/median reward -20.4/-20.5, min/max reward -21.0/-19.0
#
# Updates 204, num timesteps 209920, FPS 1171
#  Last 10 training episodes: mean/median reward -20.3/-20.0, min/max reward -21.0/-19.0
#
# Updates 205, num timesteps 210944, FPS 1171
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 206, num timesteps 211968, FPS 1172
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 207, num timesteps 212992, FPS 1172
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 208, num timesteps 214016, FPS 1173
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 209, num timesteps 215040, FPS 1174
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 210, num timesteps 216064, FPS 1174
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 211, num timesteps 217088, FPS 1174
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-19.0
#
# Updates 212, num timesteps 218112, FPS 1175
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-19.0
#
# Updates 213, num timesteps 219136, FPS 1175
#  Last 10 training episodes: mean/median reward -19.8/-20.0, min/max reward -21.0/-19.0
#
# Updates 214, num timesteps 220160, FPS 1176
#  Last 10 training episodes: mean/median reward -19.8/-20.0, min/max reward -21.0/-19.0
#
# Updates 215, num timesteps 221184, FPS 1177
#  Last 10 training episodes: mean/median reward -19.5/-19.5, min/max reward -21.0/-18.0
#
# Updates 216, num timesteps 222208, FPS 1177
#  Last 10 training episodes: mean/median reward -19.4/-19.5, min/max reward -21.0/-18.0
#
# Updates 217, num timesteps 223232, FPS 1178
#  Last 10 training episodes: mean/median reward -19.6/-20.0, min/max reward -21.0/-18.0
#
# Updates 218, num timesteps 224256, FPS 1178
#  Last 10 training episodes: mean/median reward -19.8/-20.0, min/max reward -21.0/-18.0
#
# Updates 219, num timesteps 225280, FPS 1178
#  Last 10 training episodes: mean/median reward -19.8/-20.0, min/max reward -21.0/-18.0
#
# Updates 220, num timesteps 226304, FPS 1179
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-18.0
#
# Updates 221, num timesteps 227328, FPS 1179
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-18.0
#
# Updates 222, num timesteps 228352, FPS 1180
#  Last 10 training episodes: mean/median reward -20.1/-20.5, min/max reward -21.0/-18.0
#
# Updates 223, num timesteps 229376, FPS 1180
#  Last 10 training episodes: mean/median reward -20.1/-20.5, min/max reward -21.0/-18.0
#
# Updates 224, num timesteps 230400, FPS 1181
#  Last 10 training episodes: mean/median reward -20.1/-20.5, min/max reward -21.0/-18.0
#
# Updates 225, num timesteps 231424, FPS 1181
#  Last 10 training episodes: mean/median reward -20.3/-20.5, min/max reward -21.0/-19.0
#
# Updates 226, num timesteps 232448, FPS 1182
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 227, num timesteps 233472, FPS 1182
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 228, num timesteps 234496, FPS 1182
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 229, num timesteps 235520, FPS 1183
#  Last 10 training episodes: mean/median reward -20.0/-20.0, min/max reward -21.0/-19.0
#
# Updates 230, num timesteps 236544, FPS 1183
#  Last 10 training episodes: mean/median reward -20.0/-20.0, min/max reward -21.0/-19.0
#
# Updates 231, num timesteps 237568, FPS 1184
#  Last 10 training episodes: mean/median reward -20.0/-20.0, min/max reward -21.0/-19.0
#
# Updates 232, num timesteps 238592, FPS 1184
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-19.0
#
# Updates 233, num timesteps 239616, FPS 1184
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 234, num timesteps 240640, FPS 1185
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 235, num timesteps 241664, FPS 1185
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-20.0
#
# Updates 236, num timesteps 242688, FPS 1186
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-20.0
#
# Updates 237, num timesteps 243712, FPS 1186
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-20.0
#
# Updates 238, num timesteps 244736, FPS 1187
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-20.0
#
# Updates 239, num timesteps 245760, FPS 1187
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-20.0
#
# Updates 240, num timesteps 246784, FPS 1187
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-20.0
#
# Updates 241, num timesteps 247808, FPS 1187
#  Last 10 training episodes: mean/median reward -20.4/-20.0, min/max reward -21.0/-20.0
#
# Updates 242, num timesteps 248832, FPS 1187
#  Last 10 training episodes: mean/median reward -20.4/-20.0, min/max reward -21.0/-20.0
#
# Updates 243, num timesteps 249856, FPS 1187
#  Last 10 training episodes: mean/median reward -20.4/-20.0, min/max reward -21.0/-20.0
#
# Updates 244, num timesteps 250880, FPS 1188
#  Last 10 training episodes: mean/median reward -20.4/-20.0, min/max reward -21.0/-20.0
#
# Updates 245, num timesteps 251904, FPS 1188
#  Last 10 training episodes: mean/median reward -20.4/-20.0, min/max reward -21.0/-20.0
#
# Updates 246, num timesteps 252928, FPS 1188
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 247, num timesteps 253952, FPS 1188
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-20.0
#
# Updates 248, num timesteps 254976, FPS 1188
#  Last 10 training episodes: mean/median reward -20.7/-21.0, min/max reward -21.0/-20.0
#
# Updates 249, num timesteps 256000, FPS 1188
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 250, num timesteps 257024, FPS 1188
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 251, num timesteps 258048, FPS 1188
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 252, num timesteps 259072, FPS 1189
#  Last 10 training episodes: mean/median reward -20.5/-20.5, min/max reward -21.0/-20.0
#
# Updates 253, num timesteps 260096, FPS 1189
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 254, num timesteps 261120, FPS 1189
#  Last 10 training episodes: mean/median reward -20.6/-21.0, min/max reward -21.0/-20.0
#
# Updates 255, num timesteps 262144, FPS 1189
#  Last 10 training episodes: mean/median reward -20.4/-20.5, min/max reward -21.0/-19.0
# Updates 256, num timesteps 263168, FPS 1189
#  Last 10 training episodes: mean/median reward -20.3/-20.5, min/max reward -21.0/-19.0
#
# Updates 257, num timesteps 264192, FPS 1189
#  Last 10 training episodes: mean/median reward -20.3/-20.5, min/max reward -21.0/-19.0
#
# Updates 258, num timesteps 265216, FPS 1189
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 259, num timesteps 266240, FPS 1189
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 260, num timesteps 267264, FPS 1189
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 261, num timesteps 268288, FPS 1189
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 262, num timesteps 269312, FPS 1189
#  Last 10 training episodes: mean/median reward -20.3/-20.5, min/max reward -21.0/-19.0
#
# Updates 263, num timesteps 270336, FPS 1190
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 264, num timesteps 271360, FPS 1189
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 265, num timesteps 272384, FPS 1190
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 266, num timesteps 273408, FPS 1190
#  Last 10 training episodes: mean/median reward -20.3/-20.0, min/max reward -21.0/-19.0
#
# Updates 267, num timesteps 274432, FPS 1190
#  Last 10 training episodes: mean/median reward -20.3/-20.0, min/max reward -21.0/-19.0
#
# Updates 268, num timesteps 275456, FPS 1190
#  Last 10 training episodes: mean/median reward -20.5/-21.0, min/max reward -21.0/-19.0
#
# Updates 269, num timesteps 276480, FPS 1190
#  Last 10 training episodes: mean/median reward -20.2/-20.5, min/max reward -21.0/-18.0
#
# Updates 270, num timesteps 277504, FPS 1190
#  Last 10 training episodes: mean/median reward -20.1/-20.5, min/max reward -21.0/-18.0
#
# Updates 271, num timesteps 278528, FPS 1190
#  Last 10 training episodes: mean/median reward -20.1/-20.5, min/max reward -21.0/-18.0
#
# Updates 272, num timesteps 279552, FPS 1190
#  Last 10 training episodes: mean/median reward -20.0/-20.5, min/max reward -21.0/-18.0
#
# Updates 273, num timesteps 280576, FPS 1191
#  Last 10 training episodes: mean/median reward -19.9/-20.5, min/max reward -21.0/-18.0
#
# Updates 274, num timesteps 281600, FPS 1191
#  Last 10 training episodes: mean/median reward -19.9/-20.5, min/max reward -21.0/-18.0
#
# Updates 275, num timesteps 282624, FPS 1191
#  Last 10 training episodes: mean/median reward -19.8/-20.0, min/max reward -21.0/-18.0
#
# Updates 276, num timesteps 283648, FPS 1191
#  Last 10 training episodes: mean/median reward -19.8/-20.0, min/max reward -21.0/-18.0
#
# Updates 277, num timesteps 284672, FPS 1191
#  Last 10 training episodes: mean/median reward -20.1/-21.0, min/max reward -21.0/-18.0
#
# Updates 278, num timesteps 285696, FPS 1191
#  Last 10 training episodes: mean/median reward -20.2/-21.0, min/max reward -21.0/-18.0
#
# Updates 279, num timesteps 286720, FPS 1191
#  Last 10 training episodes: mean/median reward -20.2/-21.0, min/max reward -21.0/-18.0
#
# Updates 280, num timesteps 287744, FPS 1191
#  Last 10 training episodes: mean/median reward -20.1/-20.5, min/max reward -21.0/-18.0
#
# Updates 281, num timesteps 288768, FPS 1191
#  Last 10 training episodes: mean/median reward -20.1/-20.5, min/max reward -21.0/-18.0
#
# Updates 282, num timesteps 289792, FPS 1191
#  Last 10 training episodes: mean/median reward -20.4/-20.5, min/max reward -21.0/-19.0
#
# Updates 283, num timesteps 290816, FPS 1191
#  Last 10 training episodes: mean/median reward -20.4/-20.5, min/max reward -21.0/-19.0
#
# Updates 284, num timesteps 291840, FPS 1191
#  Last 10 training episodes: mean/median reward -20.4/-20.5, min/max reward -21.0/-19.0
#
# Updates 285, num timesteps 292864, FPS 1191
#  Last 10 training episodes: mean/median reward -20.4/-20.5, min/max reward -21.0/-19.0
#
# Updates 286, num timesteps 293888, FPS 1191
#  Last 10 training episodes: mean/median reward -20.3/-20.0, min/max reward -21.0/-19.0
#
# Updates 287, num timesteps 294912, FPS 1191
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 288, num timesteps 295936, FPS 1191
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 289, num timesteps 296960, FPS 1191
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 290, num timesteps 297984, FPS 1191
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 291, num timesteps 299008, FPS 1191
#  Last 10 training episodes: mean/median reward -20.0/-20.0, min/max reward -21.0/-17.0
#
# Updates 292, num timesteps 300032, FPS 1191
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-17.0
#
# Updates 293, num timesteps 301056, FPS 1192
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-17.0
#
# Updates 294, num timesteps 302080, FPS 1191
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-17.0
#
# Updates 295, num timesteps 303104, FPS 1192
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-17.0
#
# Updates 296, num timesteps 304128, FPS 1192
#  Last 10 training episodes: mean/median reward -19.8/-20.0, min/max reward -21.0/-17.0
#
# Updates 297, num timesteps 305152, FPS 1192
#  Last 10 training episodes: mean/median reward -19.8/-20.0, min/max reward -21.0/-17.0
#
# Updates 298, num timesteps 306176, FPS 1192
#  Last 10 training episodes: mean/median reward -19.8/-20.0, min/max reward -21.0/-17.0
#
# Updates 299, num timesteps 307200, FPS 1193
#  Last 10 training episodes: mean/median reward -19.8/-20.0, min/max reward -21.0/-17.0
#
# Updates 300, num timesteps 308224, FPS 1192
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 301, num timesteps 309248, FPS 1192
#  Last 10 training episodes: mean/median reward -19.8/-20.0, min/max reward -21.0/-18.0
#
# Updates 302, num timesteps 310272, FPS 1193
#  Last 10 training episodes: mean/median reward -19.8/-20.0, min/max reward -21.0/-18.0
#
# Updates 303, num timesteps 311296, FPS 1193
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-18.0
#
# Updates 304, num timesteps 312320, FPS 1193
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-18.0
#
# Updates 305, num timesteps 313344, FPS 1193
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-18.0
#
# Updates 306, num timesteps 314368, FPS 1193
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-18.0
#
# Updates 307, num timesteps 315392, FPS 1193
#  Last 10 training episodes: mean/median reward -20.0/-20.0, min/max reward -21.0/-18.0
#
# Updates 308, num timesteps 316416, FPS 1193
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-18.0
#
# Updates 309, num timesteps 317440, FPS 1193
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-18.0
#
# Updates 310, num timesteps 318464, FPS 1193
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-18.0
#
# Updates 311, num timesteps 319488, FPS 1193
#  Last 10 training episodes: mean/median reward -20.3/-20.5, min/max reward -21.0/-18.0
#
# Updates 312, num timesteps 320512, FPS 1193
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-18.0
#
# Updates 313, num timesteps 321536, FPS 1193
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-18.0
#
# Updates 314, num timesteps 322560, FPS 1193
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-18.0
#
# Updates 315, num timesteps 323584, FPS 1194
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-18.0
#
# Updates 316, num timesteps 324608, FPS 1193
#  Last 10 training episodes: mean/median reward -20.0/-20.0, min/max reward -21.0/-18.0
#
# Updates 317, num timesteps 325632, FPS 1193
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-18.0
# Updates 318, num timesteps 326656, FPS 1194
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-18.0
#
# Updates 319, num timesteps 327680, FPS 1194
#  Last 10 training episodes: mean/median reward -20.0/-20.0, min/max reward -21.0/-18.0
#
# Updates 320, num timesteps 328704, FPS 1194
#  Last 10 training episodes: mean/median reward -20.0/-20.0, min/max reward -21.0/-18.0
#
# Updates 321, num timesteps 329728, FPS 1194
#  Last 10 training episodes: mean/median reward -20.0/-20.0, min/max reward -21.0/-18.0
#
# Updates 322, num timesteps 330752, FPS 1194
#  Last 10 training episodes: mean/median reward -20.0/-20.0, min/max reward -21.0/-18.0
#
# Updates 323, num timesteps 331776, FPS 1194
#  Last 10 training episodes: mean/median reward -20.4/-20.5, min/max reward -21.0/-19.0
#
# Updates 324, num timesteps 332800, FPS 1194
#  Last 10 training episodes: mean/median reward -20.4/-20.5, min/max reward -21.0/-19.0
#
# Updates 325, num timesteps 333824, FPS 1194
#  Last 10 training episodes: mean/median reward -20.4/-20.5, min/max reward -21.0/-19.0
#
# Updates 326, num timesteps 334848, FPS 1194
#  Last 10 training episodes: mean/median reward -20.4/-20.5, min/max reward -21.0/-19.0
#
# Updates 327, num timesteps 335872, FPS 1194
#  Last 10 training episodes: mean/median reward -20.3/-20.5, min/max reward -21.0/-19.0
#
# Updates 328, num timesteps 336896, FPS 1194
#  Last 10 training episodes: mean/median reward -20.4/-21.0, min/max reward -21.0/-19.0
#
# Updates 329, num timesteps 337920, FPS 1194
#  Last 10 training episodes: mean/median reward -20.4/-21.0, min/max reward -21.0/-19.0
#
# Updates 330, num timesteps 338944, FPS 1195
#  Last 10 training episodes: mean/median reward -20.4/-21.0, min/max reward -21.0/-19.0
#
# Updates 331, num timesteps 339968, FPS 1195
#  Last 10 training episodes: mean/median reward -20.3/-20.5, min/max reward -21.0/-19.0
#
# Updates 332, num timesteps 340992, FPS 1194
#  Last 10 training episodes: mean/median reward -20.4/-20.5, min/max reward -21.0/-19.0
#
# Updates 333, num timesteps 342016, FPS 1194
#  Last 10 training episodes: mean/median reward -20.4/-20.5, min/max reward -21.0/-19.0
#
# Updates 334, num timesteps 343040, FPS 1195
#  Last 10 training episodes: mean/median reward -20.3/-20.5, min/max reward -21.0/-19.0
#
# Updates 335, num timesteps 344064, FPS 1195
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 336, num timesteps 345088, FPS 1195
#  Last 10 training episodes: mean/median reward -20.0/-20.0, min/max reward -21.0/-19.0
#
# Updates 337, num timesteps 346112, FPS 1195
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 338, num timesteps 347136, FPS 1195
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 339, num timesteps 348160, FPS 1195
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 340, num timesteps 349184, FPS 1195
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 341, num timesteps 350208, FPS 1196
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 342, num timesteps 351232, FPS 1196
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 343, num timesteps 352256, FPS 1196
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 344, num timesteps 353280, FPS 1196
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 345, num timesteps 354304, FPS 1197
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 346, num timesteps 355328, FPS 1197
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 347, num timesteps 356352, FPS 1197
#  Last 10 training episodes: mean/median reward -20.2/-20.0, min/max reward -21.0/-19.0
#
# Updates 348, num timesteps 357376, FPS 1197
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 349, num timesteps 358400, FPS 1197
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 350, num timesteps 359424, FPS 1197
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 351, num timesteps 360448, FPS 1198
#  Last 10 training episodes: mean/median reward -20.0/-20.0, min/max reward -21.0/-19.0
#
# Updates 352, num timesteps 361472, FPS 1198
#  Last 10 training episodes: mean/median reward -20.0/-20.0, min/max reward -21.0/-19.0
#
# Updates 353, num timesteps 362496, FPS 1198
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 354, num timesteps 363520, FPS 1198
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 355, num timesteps 364544, FPS 1199
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 356, num timesteps 365568, FPS 1199
#  Last 10 training episodes: mean/median reward -20.1/-20.0, min/max reward -21.0/-19.0
#
# Updates 357, num timesteps 366592, FPS 1199
#  Last 10 training episodes: mean/median reward -20.0/-20.0, min/max reward -21.0/-19.0
#
# Updates 358, num timesteps 367616, FPS 1199
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-19.0
#
# Updates 359, num timesteps 368640, FPS 1200
#  Last 10 training episodes: mean/median reward -19.8/-20.0, min/max reward -21.0/-18.0
#
# Updates 360, num timesteps 369664, FPS 1200
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-18.0
#
# Updates 361, num timesteps 370688, FPS 1200
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-18.0
#
# Updates 362, num timesteps 371712, FPS 1200
#  Last 10 training episodes: mean/median reward -19.7/-20.0, min/max reward -21.0/-18.0
#
# Updates 363, num timesteps 372736, FPS 1200
#  Last 10 training episodes: mean/median reward -19.7/-20.0, min/max reward -21.0/-18.0
#
# Updates 364, num timesteps 373760, FPS 1201
#  Last 10 training episodes: mean/median reward -19.7/-20.0, min/max reward -21.0/-18.0
#
# Updates 365, num timesteps 374784, FPS 1201
#  Last 10 training episodes: mean/median reward -19.7/-20.0, min/max reward -21.0/-18.0
#
# Updates 366, num timesteps 375808, FPS 1201
#  Last 10 training episodes: mean/median reward -19.9/-20.0, min/max reward -21.0/-18.0
#
# Updates 367, num timesteps 376832, FPS 1201
#  Last 10 training episodes: mean/median reward -20.0/-20.5, min/max reward -21.0/-18.0
#
# Updates 368, num timesteps 377856, FPS 1201
# ...
# Updates 9643, num timesteps 9875456, FPS 1269
#  Last 10 training episodes: mean/median reward 20.0/21.0, min/max reward 16.0/21.0
#
# Updates 9644, num timesteps 9876480, FPS 1269
#  Last 10 training episodes: mean/median reward 20.0/21.0, min/max reward 16.0/21.0
#
# Updates 9645, num timesteps 9877504, FPS 1269
#  Last 10 training episodes: mean/median reward 20.0/21.0, min/max reward 16.0/21.0
#
# Updates 9646, num timesteps 9878528, FPS 1269
#  Last 10 training episodes: mean/median reward 20.0/21.0, min/max reward 16.0/21.0
#
# Updates 9647, num timesteps 9879552, FPS 1269
#  Last 10 training episodes: mean/median reward 19.8/21.0, min/max reward 16.0/21.0
#
# Updates 9648, num timesteps 9880576, FPS 1269
#  Last 10 training episodes: mean/median reward 19.5/20.5, min/max reward 16.0/21.0
#
# Updates 9649, num timesteps 9881600, FPS 1269
#  Last 10 training episodes: mean/median reward 19.5/20.5, min/max reward 16.0/21.0
#
# Updates 9650, num timesteps 9882624, FPS 1269
#  Last 10 training episodes: mean/median reward 19.5/20.5, min/max reward 16.0/21.0
#
# Updates 9651, num timesteps 9883648, FPS 1269
#  Last 10 training episodes: mean/median reward 19.5/20.5, min/max reward 16.0/21.0
#
# Updates 9652, num timesteps 9884672, FPS 1269
#  Last 10 training episodes: mean/median reward 19.5/20.5, min/max reward 16.0/21.0
#
# Updates 9653, num timesteps 9885696, FPS 1269
#  Last 10 training episodes: mean/median reward 19.5/20.5, min/max reward 16.0/21.0
#
# Updates 9654, num timesteps 9886720, FPS 1269
#  Last 10 training episodes: mean/median reward 19.3/19.5, min/max reward 16.0/21.0
#
# Updates 9655, num timesteps 9887744, FPS 1269
#  Last 10 training episodes: mean/median reward 19.3/19.5, min/max reward 16.0/21.0
#
# Updates 9656, num timesteps 9888768, FPS 1269
#  Last 10 training episodes: mean/median reward 19.3/19.5, min/max reward 16.0/21.0
#
# Updates 9657, num timesteps 9889792, FPS 1269
#  Last 10 training episodes: mean/median reward 19.0/19.0, min/max reward 16.0/21.0
#
# Updates 9658, num timesteps 9890816, FPS 1269
#  Last 10 training episodes: mean/median reward 19.0/19.0, min/max reward 16.0/21.0
#
# Updates 9659, num timesteps 9891840, FPS 1269
#  Last 10 training episodes: mean/median reward 19.0/19.0, min/max reward 16.0/21.0
#
# Updates 9660, num timesteps 9892864, FPS 1269
#  Last 10 training episodes: mean/median reward 19.0/19.0, min/max reward 16.0/21.0
#
# Updates 9661, num timesteps 9893888, FPS 1269
#  Last 10 training episodes: mean/median reward 19.0/19.0, min/max reward 16.0/21.0
#
# Updates 9662, num timesteps 9894912, FPS 1269
#  Last 10 training episodes: mean/median reward 19.0/19.0, min/max reward 16.0/21.0
#
# Updates 9663, num timesteps 9895936, FPS 1269
#  Last 10 training episodes: mean/median reward 19.5/19.5, min/max reward 17.0/21.0
#
# Updates 9664, num timesteps 9896960, FPS 1269
#  Last 10 training episodes: mean/median reward 19.4/19.5, min/max reward 17.0/21.0
#
# Updates 9665, num timesteps 9897984, FPS 1269
#  Last 10 training episodes: mean/median reward 19.6/20.0, min/max reward 17.0/21.0
#
# Updates 9666, num timesteps 9899008, FPS 1269
#  Last 10 training episodes: mean/median reward 19.5/19.5, min/max reward 17.0/21.0
#
# Updates 9667, num timesteps 9900032, FPS 1269
#  Last 10 training episodes: mean/median reward 19.5/19.5, min/max reward 17.0/21.0
#
# Updates 9668, num timesteps 9901056, FPS 1269
#  Last 10 training episodes: mean/median reward 19.6/19.5, min/max reward 18.0/21.0
#
# Updates 9669, num timesteps 9902080, FPS 1269
#  Last 10 training episodes: mean/median reward 19.9/20.5, min/max reward 18.0/21.0
#
# Updates 9670, num timesteps 9903104, FPS 1269
#  Last 10 training episodes: mean/median reward 19.9/20.5, min/max reward 18.0/21.0
#
# Updates 9671, num timesteps 9904128, FPS 1269
#  Last 10 training episodes: mean/median reward 19.9/20.5, min/max reward 18.0/21.0
#
# Updates 9672, num timesteps 9905152, FPS 1269
#  Last 10 training episodes: mean/median reward 19.9/20.5, min/max reward 18.0/21.0
#
# Updates 9673, num timesteps 9906176, FPS 1269
#  Last 10 training episodes: mean/median reward 19.9/20.5, min/max reward 18.0/21.0
#
# Updates 9674, num timesteps 9907200, FPS 1269
#  Last 10 training episodes: mean/median reward 19.9/20.5, min/max reward 18.0/21.0
#
# Updates 9675, num timesteps 9908224, FPS 1269
#  Last 10 training episodes: mean/median reward 19.9/20.5, min/max reward 18.0/21.0
#
# Updates 9676, num timesteps 9909248, FPS 1269
#  Last 10 training episodes: mean/median reward 19.9/20.5, min/max reward 18.0/21.0
#
# Updates 9677, num timesteps 9910272, FPS 1269
#  Last 10 training episodes: mean/median reward 19.9/20.5, min/max reward 18.0/21.0
#
# Updates 9678, num timesteps 9911296, FPS 1269
#  Last 10 training episodes: mean/median reward 19.9/20.5, min/max reward 18.0/21.0
#
# Updates 9679, num timesteps 9912320, FPS 1269
#  Last 10 training episodes: mean/median reward 19.9/20.5, min/max reward 18.0/21.0
#
# Updates 9680, num timesteps 9913344, FPS 1269
#  Last 10 training episodes: mean/median reward 19.9/20.5, min/max reward 18.0/21.0
#
# Updates 9681, num timesteps 9914368, FPS 1269
#  Last 10 training episodes: mean/median reward 19.9/20.5, min/max reward 18.0/21.0
#
# Updates 9682, num timesteps 9915392, FPS 1269
#  Last 10 training episodes: mean/median reward 20.1/21.0, min/max reward 18.0/21.0
#
# Updates 9683, num timesteps 9916416, FPS 1269
#  Last 10 training episodes: mean/median reward 20.1/21.0, min/max reward 18.0/21.0
#
# Updates 9684, num timesteps 9917440, FPS 1269
#  Last 10 training episodes: mean/median reward 20.1/21.0, min/max reward 18.0/21.0
#
# Updates 9685, num timesteps 9918464, FPS 1269
#  Last 10 training episodes: mean/median reward 20.4/21.0, min/max reward 18.0/21.0
#
# Updates 9686, num timesteps 9919488, FPS 1269
#  Last 10 training episodes: mean/median reward 20.4/21.0, min/max reward 18.0/21.0
#
# Updates 9687, num timesteps 9920512, FPS 1269
#  Last 10 training episodes: mean/median reward 20.0/21.0, min/max reward 17.0/21.0
#
# Updates 9688, num timesteps 9921536, FPS 1269
#  Last 10 training episodes: mean/median reward 20.0/21.0, min/max reward 17.0/21.0
#
# Updates 9689, num timesteps 9922560, FPS 1269
#  Last 10 training episodes: mean/median reward 20.1/21.0, min/max reward 17.0/21.0
#
# Updates 9690, num timesteps 9923584, FPS 1269
#  Last 10 training episodes: mean/median reward 20.1/21.0, min/max reward 17.0/21.0
#
# Updates 9691, num timesteps 9924608, FPS 1269
#  Last 10 training episodes: mean/median reward 19.9/21.0, min/max reward 17.0/21.0
#
# Updates 9692, num timesteps 9925632, FPS 1269
#  Last 10 training episodes: mean/median reward 19.9/21.0, min/max reward 17.0/21.0
#
# Updates 9693, num timesteps 9926656, FPS 1269
#  Last 10 training episodes: mean/median reward 19.9/21.0, min/max reward 17.0/21.0
#
# Updates 9694, num timesteps 9927680, FPS 1269
#  Last 10 training episodes: mean/median reward 19.9/21.0, min/max reward 17.0/21.0
#
# Updates 9695, num timesteps 9928704, FPS 1269
#  Last 10 training episodes: mean/median reward 19.9/21.0, min/max reward 17.0/21.0
#
# Updates 9696, num timesteps 9929728, FPS 1269
#  Last 10 training episodes: mean/median reward 20.1/21.0, min/max reward 17.0/21.0
#
# Updates 9697, num timesteps 9930752, FPS 1269
#  Last 10 training episodes: mean/median reward 20.2/21.0, min/max reward 17.0/21.0
#
# Updates 9698, num timesteps 9931776, FPS 1269
#  Last 10 training episodes: mean/median reward 19.4/21.0, min/max reward 13.0/21.0
#
# Updates 9699, num timesteps 9932800, FPS 1269
#  Last 10 training episodes: mean/median reward 19.4/21.0, min/max reward 13.0/21.0
#
# Updates 9700, num timesteps 9933824, FPS 1269
#  Last 10 training episodes: mean/median reward 19.4/21.0, min/max reward 13.0/21.0
#
# Updates 9701, num timesteps 9934848, FPS 1269
#  Last 10 training episodes: mean/median reward 19.1/20.0, min/max reward 13.0/21.0
#
# Updates 9702, num timesteps 9935872, FPS 1269
#  Last 10 training episodes: mean/median reward 19.1/20.0, min/max reward 13.0/21.0
#
# Updates 9703, num timesteps 9936896, FPS 1269
#  Last 10 training episodes: mean/median reward 19.1/20.0, min/max reward 13.0/21.0
#
# Updates 9704, num timesteps 9937920, FPS 1269
#  Last 10 training episodes: mean/median reward 19.1/20.0, min/max reward 13.0/21.0
#
# Updates 9705, num timesteps 9938944, FPS 1269
#  Last 10 training episodes: mean/median reward 19.1/20.0, min/max reward 13.0/21.0
# Updates 9706, num timesteps 9939968, FPS 1269
#  Last 10 training episodes: mean/median reward 19.1/20.0, min/max reward 13.0/21.0
#
# Updates 9707, num timesteps 9940992, FPS 1269
#  Last 10 training episodes: mean/median reward 19.1/20.0, min/max reward 13.0/21.0
#
# Updates 9708, num timesteps 9942016, FPS 1269
#  Last 10 training episodes: mean/median reward 19.1/20.0, min/max reward 13.0/21.0
#
# Updates 9709, num timesteps 9943040, FPS 1269
#  Last 10 training episodes: mean/median reward 19.1/20.0, min/max reward 13.0/21.0
#
# Updates 9710, num timesteps 9944064, FPS 1269
#  Last 10 training episodes: mean/median reward 19.1/20.0, min/max reward 13.0/21.0
#
# Updates 9711, num timesteps 9945088, FPS 1269
#  Last 10 training episodes: mean/median reward 19.1/20.0, min/max reward 13.0/21.0
#
# Updates 9712, num timesteps 9946112, FPS 1269
#  Last 10 training episodes: mean/median reward 19.1/20.0, min/max reward 13.0/21.0
#
# Updates 9713, num timesteps 9947136, FPS 1269
#  Last 10 training episodes: mean/median reward 19.4/20.5, min/max reward 13.0/21.0
#
# Updates 9714, num timesteps 9948160, FPS 1269
#  Last 10 training episodes: mean/median reward 19.4/20.5, min/max reward 13.0/21.0
#
# Updates 9715, num timesteps 9949184, FPS 1269
#  Last 10 training episodes: mean/median reward 19.4/20.5, min/max reward 13.0/21.0
#
# Updates 9716, num timesteps 9950208, FPS 1269
#  Last 10 training episodes: mean/median reward 19.6/21.0, min/max reward 13.0/21.0
#
# Updates 9717, num timesteps 9951232, FPS 1269
#  Last 10 training episodes: mean/median reward 19.6/21.0, min/max reward 13.0/21.0
#
# Updates 9718, num timesteps 9952256, FPS 1269
#  Last 10 training episodes: mean/median reward 19.6/21.0, min/max reward 13.0/21.0
#
# Updates 9719, num timesteps 9953280, FPS 1269
#  Last 10 training episodes: mean/median reward 20.3/21.0, min/max reward 18.0/21.0
#
# Updates 9720, num timesteps 9954304, FPS 1269
#  Last 10 training episodes: mean/median reward 20.3/21.0, min/max reward 18.0/21.0
#
# Updates 9721, num timesteps 9955328, FPS 1269
#  Last 10 training episodes: mean/median reward 20.3/21.0, min/max reward 18.0/21.0
#
# Updates 9722, num timesteps 9956352, FPS 1269
#  Last 10 training episodes: mean/median reward 20.3/21.0, min/max reward 18.0/21.0
#
# Updates 9723, num timesteps 9957376, FPS 1269
#  Last 10 training episodes: mean/median reward 20.3/21.0, min/max reward 18.0/21.0
#
# Updates 9724, num timesteps 9958400, FPS 1269
#  Last 10 training episodes: mean/median reward 20.3/21.0, min/max reward 18.0/21.0
#
# Updates 9725, num timesteps 9959424, FPS 1269
#  Last 10 training episodes: mean/median reward 20.3/21.0, min/max reward 18.0/21.0
#
# Updates 9726, num timesteps 9960448, FPS 1269
#  Last 10 training episodes: mean/median reward 20.3/21.0, min/max reward 18.0/21.0
#
# Updates 9727, num timesteps 9961472, FPS 1269
#  Last 10 training episodes: mean/median reward 20.2/20.5, min/max reward 18.0/21.0
#
# Updates 9728, num timesteps 9962496, FPS 1269
#  Last 10 training episodes: mean/median reward 20.5/21.0, min/max reward 19.0/21.0
#
# Updates 9729, num timesteps 9963520, FPS 1269
#  Last 10 training episodes: mean/median reward 20.5/21.0, min/max reward 19.0/21.0
#
# Updates 9730, num timesteps 9964544, FPS 1269
#  Last 10 training episodes: mean/median reward 20.5/21.0, min/max reward 19.0/21.0
#
# Updates 9731, num timesteps 9965568, FPS 1269
#  Last 10 training episodes: mean/median reward 20.5/21.0, min/max reward 19.0/21.0
#
# Updates 9732, num timesteps 9966592, FPS 1269
#  Last 10 training episodes: mean/median reward 20.5/21.0, min/max reward 19.0/21.0
#
# Updates 9733, num timesteps 9967616, FPS 1269
#  Last 10 training episodes: mean/median reward 20.5/21.0, min/max reward 19.0/21.0
#
# Updates 9734, num timesteps 9968640, FPS 1269
#  Last 10 training episodes: mean/median reward 20.5/21.0, min/max reward 19.0/21.0
#
# Updates 9735, num timesteps 9969664, FPS 1269
#  Last 10 training episodes: mean/median reward 20.4/20.5, min/max reward 19.0/21.0
#
# Updates 9736, num timesteps 9970688, FPS 1269
#  Last 10 training episodes: mean/median reward 20.4/20.5, min/max reward 19.0/21.0
#
# Updates 9737, num timesteps 9971712, FPS 1269
#  Last 10 training episodes: mean/median reward 20.4/20.5, min/max reward 19.0/21.0
#
# Updates 9738, num timesteps 9972736, FPS 1269
#  Last 10 training episodes: mean/median reward 20.5/21.0, min/max reward 19.0/21.0
#
# Updates 9739, num timesteps 9973760, FPS 1269
#  Last 10 training episodes: mean/median reward 20.5/21.0, min/max reward 19.0/21.0
#
# Updates 9740, num timesteps 9974784, FPS 1269
#  Last 10 training episodes: mean/median reward 20.6/21.0, min/max reward 20.0/21.0
#
# Updates 9741, num timesteps 9975808, FPS 1269
#  Last 10 training episodes: mean/median reward 20.6/21.0, min/max reward 20.0/21.0
#
# Updates 9742, num timesteps 9976832, FPS 1269
#  Last 10 training episodes: mean/median reward 20.6/21.0, min/max reward 20.0/21.0
#
# Updates 9743, num timesteps 9977856, FPS 1269
#  Last 10 training episodes: mean/median reward 20.6/21.0, min/max reward 20.0/21.0
#
# Updates 9744, num timesteps 9978880, FPS 1269
#  Last 10 training episodes: mean/median reward 20.7/21.0, min/max reward 20.0/21.0
#
# Updates 9745, num timesteps 9979904, FPS 1269
#  Last 10 training episodes: mean/median reward 20.7/21.0, min/max reward 20.0/21.0
#
# Updates 9746, num timesteps 9980928, FPS 1269
#  Last 10 training episodes: mean/median reward 20.7/21.0, min/max reward 20.0/21.0
#
# Updates 9747, num timesteps 9981952, FPS 1269
#  Last 10 training episodes: mean/median reward 20.7/21.0, min/max reward 20.0/21.0
#
# Updates 9748, num timesteps 9982976, FPS 1269
#  Last 10 training episodes: mean/median reward 20.7/21.0, min/max reward 20.0/21.0
#
# Updates 9749, num timesteps 9984000, FPS 1269
#  Last 10 training episodes: mean/median reward 20.7/21.0, min/max reward 20.0/21.0
#
# Updates 9750, num timesteps 9985024, FPS 1269
#  Last 10 training episodes: mean/median reward 20.7/21.0, min/max reward 20.0/21.0
#
# Updates 9751, num timesteps 9986048, FPS 1269
#  Last 10 training episodes: mean/median reward 20.8/21.0, min/max reward 20.0/21.0
#
# Updates 9752, num timesteps 9987072, FPS 1269
#  Last 10 training episodes: mean/median reward 20.8/21.0, min/max reward 20.0/21.0
#
# Updates 9753, num timesteps 9988096, FPS 1269
#  Last 10 training episodes: mean/median reward 20.8/21.0, min/max reward 20.0/21.0
#
# Updates 9754, num timesteps 9989120, FPS 1269
#  Last 10 training episodes: mean/median reward 20.8/21.0, min/max reward 20.0/21.0
#
# Updates 9755, num timesteps 9990144, FPS 1269
#  Last 10 training episodes: mean/median reward 20.8/21.0, min/max reward 20.0/21.0
#
# Updates 9756, num timesteps 9991168, FPS 1269
#  Last 10 training episodes: mean/median reward 20.9/21.0, min/max reward 20.0/21.0
#
# Updates 9757, num timesteps 9992192, FPS 1269
#  Last 10 training episodes: mean/median reward 20.6/21.0, min/max reward 18.0/21.0
#
# Updates 9758, num timesteps 9993216, FPS 1269
#  Last 10 training episodes: mean/median reward 20.6/21.0, min/max reward 18.0/21.0
#
# Updates 9759, num timesteps 9994240, FPS 1269
#  Last 10 training episodes: mean/median reward 20.5/21.0, min/max reward 18.0/21.0
#
# Updates 9760, num timesteps 9995264, FPS 1269
#  Last 10 training episodes: mean/median reward 20.5/21.0, min/max reward 18.0/21.0
#
# Updates 9761, num timesteps 9996288, FPS 1269
#  Last 10 training episodes: mean/median reward 20.6/21.0, min/max reward 18.0/21.0
#
# Updates 9762, num timesteps 9997312, FPS 1269
#  Last 10 training episodes: mean/median reward 20.6/21.0, min/max reward 18.0/21.0
#
# Updates 9763, num timesteps 9998336, FPS 1269
#  Last 10 training episodes: mean/median reward 20.6/21.0, min/max reward 18.0/21.0
#
# Updates 9764, num timesteps 9999360, FPS 1269
#  Last 10 training episodes: mean/median reward 20.6/21.0, min/max reward 18.0/21.0

# %%
import torch
#?torch.zeros(10).copy_()
# ?torch.Tensor.copy_

# %%
8*306*16*64*4
# Out:
# 10027008

# %%
# !cd pytorch-a2c-ppo-acktr && python main.py --env-name "KungFuMasterNoFrameskip-v0" --algo ppo --use-gae --lr 2.5e-4 --clip-param 0.1 --value-loss-coef 1 --num-processes 16 --num-steps 64 --num-mini-batch 4 --vis-interval 1 --log-interval 1 --log-dir ./logs
# Out:
# Updates 12, num timesteps 13312, FPS 1529
#  Last 2 training episodes: mean/median reward 500.0/500.0, min/max reward 300.0/700.0
#
# Updates 13, num timesteps 14336, FPS 1551
#  Last 2 training episodes: mean/median reward 500.0/500.0, min/max reward 300.0/700.0
#
# Updates 14, num timesteps 15360, FPS 1554
#  Last 5 training episodes: mean/median reward 480.0/500.0, min/max reward 300.0/700.0
#
# Updates 15, num timesteps 16384, FPS 1538
#  Last 10 training episodes: mean/median reward 490.0/450.0, min/max reward 0.0/900.0
#
# Updates 16, num timesteps 17408, FPS 1547
#  Last 10 training episodes: mean/median reward 510.0/450.0, min/max reward 0.0/900.0
#
# Updates 17, num timesteps 18432, FPS 1563
#  Last 10 training episodes: mean/median reward 510.0/450.0, min/max reward 0.0/900.0
#
# Updates 18, num timesteps 19456, FPS 1570
#  Last 10 training episodes: mean/median reward 630.0/650.0, min/max reward 0.0/1400.0
#
# Updates 19, num timesteps 20480, FPS 1580
#  Last 10 training episodes: mean/median reward 680.0/650.0, min/max reward 0.0/1400.0
#
# Updates 20, num timesteps 21504, FPS 1589
#  Last 10 training episodes: mean/median reward 680.0/650.0, min/max reward 0.0/1400.0
#
# Updates 21, num timesteps 22528, FPS 1599
#  Last 10 training episodes: mean/median reward 680.0/650.0, min/max reward 0.0/1400.0
#
# Updates 22, num timesteps 23552, FPS 1610
#  Last 10 training episodes: mean/median reward 680.0/650.0, min/max reward 0.0/1400.0
#
# Updates 23, num timesteps 24576, FPS 1620
#  Last 10 training episodes: mean/median reward 680.0/650.0, min/max reward 0.0/1400.0
#
# Updates 24, num timesteps 25600, FPS 1631
#  Last 10 training episodes: mean/median reward 680.0/650.0, min/max reward 0.0/1400.0
#
# Updates 25, num timesteps 26624, FPS 1641
#  Last 10 training episodes: mean/median reward 680.0/650.0, min/max reward 0.0/1400.0
#
# Updates 26, num timesteps 27648, FPS 1650
#  Last 10 training episodes: mean/median reward 680.0/650.0, min/max reward 0.0/1400.0
#
# Updates 27, num timesteps 28672, FPS 1657
#  Last 10 training episodes: mean/median reward 790.0/800.0, min/max reward 0.0/1400.0
#
# Updates 28, num timesteps 29696, FPS 1667
#  Last 10 training episodes: mean/median reward 790.0/800.0, min/max reward 0.0/1400.0
#
# Updates 29, num timesteps 30720, FPS 1662
#  Last 10 training episodes: mean/median reward 890.0/800.0, min/max reward 400.0/1400.0
#
# Updates 30, num timesteps 31744, FPS 1665
#  Last 10 training episodes: mean/median reward 1050.0/950.0, min/max reward 600.0/1600.0
#
# Updates 31, num timesteps 32768, FPS 1665
#  Last 10 training episodes: mean/median reward 1080.0/950.0, min/max reward 600.0/1700.0
#
# Updates 32, num timesteps 33792, FPS 1669
#  Last 10 training episodes: mean/median reward 1120.0/1050.0, min/max reward 600.0/1700.0
#
# Updates 33, num timesteps 34816, FPS 1670
#  Last 10 training episodes: mean/median reward 1150.0/1150.0, min/max reward 600.0/1700.0
#
# Updates 34, num timesteps 35840, FPS 1672
#  Last 10 training episodes: mean/median reward 1130.0/1150.0, min/max reward 600.0/1700.0
#
# Updates 35, num timesteps 36864, FPS 1675
#  Last 10 training episodes: mean/median reward 1180.0/1150.0, min/max reward 600.0/1800.0
#
# Updates 36, num timesteps 37888, FPS 1685
#  Last 10 training episodes: mean/median reward 1180.0/1150.0, min/max reward 600.0/1800.0
#
# Updates 37, num timesteps 38912, FPS 1689
#  Last 10 training episodes: mean/median reward 1430.0/1300.0, min/max reward 600.0/3300.0
#
# Updates 38, num timesteps 39936, FPS 1695
#  Last 10 training episodes: mean/median reward 1430.0/1300.0, min/max reward 600.0/3300.0
#
# Updates 39, num timesteps 40960, FPS 1700
#  Last 10 training episodes: mean/median reward 1410.0/1300.0, min/max reward 400.0/3300.0
#
# Updates 40, num timesteps 41984, FPS 1704
#  Last 10 training episodes: mean/median reward 1410.0/1300.0, min/max reward 400.0/3300.0
#
# Updates 41, num timesteps 43008, FPS 1705
#  Last 10 training episodes: mean/median reward 1550.0/1500.0, min/max reward 400.0/3300.0
#
# Updates 42, num timesteps 44032, FPS 1708
#  Last 10 training episodes: mean/median reward 1640.0/1550.0, min/max reward 400.0/3300.0
#
# Updates 43, num timesteps 45056, FPS 1712
#  Last 10 training episodes: mean/median reward 1640.0/1550.0, min/max reward 400.0/3300.0
#
# Updates 44, num timesteps 46080, FPS 1719
#  Last 10 training episodes: mean/median reward 1640.0/1550.0, min/max reward 400.0/3300.0
#
# Updates 45, num timesteps 47104, FPS 1724
#  Last 10 training episodes: mean/median reward 1570.0/1300.0, min/max reward 400.0/3300.0
#
# Updates 46, num timesteps 48128, FPS 1729
#  Last 10 training episodes: mean/median reward 1570.0/1300.0, min/max reward 400.0/3300.0
#
# Updates 47, num timesteps 49152, FPS 1735
#  Last 10 training episodes: mean/median reward 1570.0/1300.0, min/max reward 400.0/3300.0
#
# Updates 48, num timesteps 50176, FPS 1740
#  Last 10 training episodes: mean/median reward 1570.0/1300.0, min/max reward 400.0/3300.0
#
# Updates 49, num timesteps 51200, FPS 1744
#  Last 10 training episodes: mean/median reward 1620.0/1500.0, min/max reward 400.0/3300.0
#
# Updates 50, num timesteps 52224, FPS 1741
#  Last 10 training episodes: mean/median reward 2030.0/2400.0, min/max reward 400.0/3300.0
#
# Updates 51, num timesteps 53248, FPS 1746
#  Last 10 training episodes: mean/median reward 2030.0/2400.0, min/max reward 400.0/3300.0
#
# Updates 52, num timesteps 54272, FPS 1751
#  Last 10 training episodes: mean/median reward 2030.0/2400.0, min/max reward 400.0/3300.0
#
# Updates 53, num timesteps 55296, FPS 1755
#  Last 10 training episodes: mean/median reward 2190.0/2400.0, min/max reward 400.0/3400.0
#
# Updates 54, num timesteps 56320, FPS 1759
#  Last 10 training episodes: mean/median reward 2190.0/2400.0, min/max reward 400.0/3400.0
#
# Updates 55, num timesteps 57344, FPS 1764
#  Last 10 training episodes: mean/median reward 2190.0/2400.0, min/max reward 400.0/3400.0
#
# Updates 56, num timesteps 58368, FPS 1762
#  Last 10 training episodes: mean/median reward 2480.0/2450.0, min/max reward 1000.0/3700.0
#
# Updates 57, num timesteps 59392, FPS 1762
#  Last 10 training episodes: mean/median reward 2510.0/2450.0, min/max reward 1000.0/3700.0
#
# Updates 58, num timesteps 60416, FPS 1761
#  Last 10 training episodes: mean/median reward 2630.0/2450.0, min/max reward 1600.0/3700.0
#
# Updates 59, num timesteps 61440, FPS 1763
#  Last 10 training episodes: mean/median reward 2630.0/2450.0, min/max reward 1600.0/3700.0
#
# Updates 60, num timesteps 62464, FPS 1764
#  Last 10 training episodes: mean/median reward 2630.0/2450.0, min/max reward 1600.0/3700.0
#
# Updates 61, num timesteps 63488, FPS 1765
#  Last 10 training episodes: mean/median reward 2850.0/2650.0, min/max reward 2200.0/3800.0
#
# Updates 62, num timesteps 64512, FPS 1764
#  Last 10 training episodes: mean/median reward 2950.0/2850.0, min/max reward 2100.0/3800.0
#
# Updates 63, num timesteps 65536, FPS 1765
#  Last 10 training episodes: mean/median reward 2950.0/2850.0, min/max reward 2100.0/3800.0
#
# Updates 64, num timesteps 66560, FPS 1763
#  Last 10 training episodes: mean/median reward 3270.0/3150.0, min/max reward 2100.0/5700.0
#
# Updates 65, num timesteps 67584, FPS 1763
#  Last 10 training episodes: mean/median reward 3270.0/3150.0, min/max reward 2100.0/5700.0
#
# Updates 66, num timesteps 68608, FPS 1762
#  Last 10 training episodes: mean/median reward 3270.0/3150.0, min/max reward 2100.0/5700.0
#
# Updates 67, num timesteps 69632, FPS 1763
#  Last 10 training episodes: mean/median reward 3110.0/2850.0, min/max reward 1800.0/5700.0
#
# Updates 68, num timesteps 70656, FPS 1763
#  Last 10 training episodes: mean/median reward 3110.0/2850.0, min/max reward 1800.0/5700.0
#
# Updates 69, num timesteps 71680, FPS 1763
#  Last 10 training episodes: mean/median reward 3180.0/3200.0, min/max reward 1800.0/5700.0
#
# Updates 70, num timesteps 72704, FPS 1760
#  Last 10 training episodes: mean/median reward 3290.0/3200.0, min/max reward 1800.0/5700.0
#
# Updates 71, num timesteps 73728, FPS 1758
#  Last 10 training episodes: mean/median reward 3370.0/3400.0, min/max reward 1800.0/5700.0
#
# Updates 72, num timesteps 74752, FPS 1755
#  Last 10 training episodes: mean/median reward 3290.0/3400.0, min/max reward 1800.0/5700.0
#
# Updates 73, num timesteps 75776, FPS 1755
#  Last 10 training episodes: mean/median reward 3290.0/3400.0, min/max reward 1800.0/5700.0
# Updates 74, num timesteps 76800, FPS 1755
#  Last 10 training episodes: mean/median reward 3690.0/3650.0, min/max reward 1800.0/6200.0
#
# Updates 75, num timesteps 77824, FPS 1756
#  Last 10 training episodes: mean/median reward 3690.0/3650.0, min/max reward 1800.0/6200.0
#
# Updates 76, num timesteps 78848, FPS 1758
#  Last 10 training episodes: mean/median reward 3690.0/3650.0, min/max reward 1800.0/6200.0
#
# Updates 77, num timesteps 79872, FPS 1759
#  Last 10 training episodes: mean/median reward 3690.0/3650.0, min/max reward 1800.0/6200.0
#
# Updates 78, num timesteps 80896, FPS 1759
#  Last 10 training episodes: mean/median reward 3690.0/3650.0, min/max reward 1800.0/6200.0
#
# Updates 79, num timesteps 81920, FPS 1760
#  Last 10 training episodes: mean/median reward 3680.0/3650.0, min/max reward 1800.0/6200.0
#
# Updates 80, num timesteps 82944, FPS 1761
#  Last 10 training episodes: mean/median reward 3680.0/3650.0, min/max reward 1800.0/6200.0
#
# Updates 81, num timesteps 83968, FPS 1762
#  Last 10 training episodes: mean/median reward 3680.0/3650.0, min/max reward 1800.0/6200.0
#
# Updates 82, num timesteps 84992, FPS 1764
#  Last 10 training episodes: mean/median reward 3680.0/3650.0, min/max reward 1800.0/6200.0
#
# Updates 83, num timesteps 86016, FPS 1765
#  Last 10 training episodes: mean/median reward 3680.0/3650.0, min/max reward 1800.0/6200.0
#
# Updates 84, num timesteps 87040, FPS 1757
#  Last 10 training episodes: mean/median reward 3720.0/3450.0, min/max reward 2000.0/6200.0
#
# Updates 85, num timesteps 88064, FPS 1755
#  Last 10 training episodes: mean/median reward 3840.0/3700.0, min/max reward 2000.0/6200.0
#
# Updates 86, num timesteps 89088, FPS 1752
#  Last 10 training episodes: mean/median reward 3880.0/3700.0, min/max reward 2400.0/6200.0
#
# Updates 87, num timesteps 90112, FPS 1752
#  Last 10 training episodes: mean/median reward 3770.0/3700.0, min/max reward 2400.0/5900.0
#
# Updates 88, num timesteps 91136, FPS 1753
#  Last 10 training episodes: mean/median reward 3770.0/3700.0, min/max reward 2400.0/5900.0
#
# Updates 89, num timesteps 92160, FPS 1756
#  Last 10 training episodes: mean/median reward 3770.0/3700.0, min/max reward 2400.0/5900.0
#
# Updates 90, num timesteps 93184, FPS 1758
#  Last 10 training episodes: mean/median reward 3770.0/3700.0, min/max reward 2400.0/5900.0
#
# Updates 91, num timesteps 94208, FPS 1761
#  Last 10 training episodes: mean/median reward 3710.0/3400.0, min/max reward 2400.0/5900.0
#
# Updates 92, num timesteps 95232, FPS 1764
#  Last 10 training episodes: mean/median reward 3710.0/3400.0, min/max reward 2400.0/5900.0
#
# Updates 93, num timesteps 96256, FPS 1766
#  Last 10 training episodes: mean/median reward 3710.0/3400.0, min/max reward 2400.0/5900.0
#
# Updates 94, num timesteps 97280, FPS 1764
#  Last 10 training episodes: mean/median reward 3940.0/3700.0, min/max reward 2400.0/5900.0
#
# Updates 95, num timesteps 98304, FPS 1765
#  Last 10 training episodes: mean/median reward 3940.0/3700.0, min/max reward 2400.0/5900.0
#
# Updates 96, num timesteps 99328, FPS 1768
#  Last 10 training episodes: mean/median reward 3940.0/3700.0, min/max reward 2400.0/5900.0
#
# Updates 97, num timesteps 100352, FPS 1769
#  Last 10 training episodes: mean/median reward 4030.0/3700.0, min/max reward 2400.0/5900.0
#
# Updates 98, num timesteps 101376, FPS 1771
#  Last 10 training episodes: mean/median reward 4030.0/3700.0, min/max reward 2400.0/5900.0
#
# Updates 99, num timesteps 102400, FPS 1773
#  Last 10 training episodes: mean/median reward 4120.0/3950.0, min/max reward 2400.0/5900.0
#
# Updates 100, num timesteps 103424, FPS 1774
#  Last 10 training episodes: mean/median reward 4120.0/3950.0, min/max reward 2400.0/5900.0
#
# Updates 101, num timesteps 104448, FPS 1777
#  Last 10 training episodes: mean/median reward 4120.0/3950.0, min/max reward 2400.0/5900.0
#
# Updates 102, num timesteps 105472, FPS 1778
#  Last 10 training episodes: mean/median reward 3590.0/3650.0, min/max reward 1000.0/5600.0
#
# Updates 103, num timesteps 106496, FPS 1780
#  Last 10 training episodes: mean/median reward 3590.0/3650.0, min/max reward 1000.0/5600.0
#
# Updates 104, num timesteps 107520, FPS 1781
#  Last 10 training episodes: mean/median reward 3670.0/3650.0, min/max reward 1000.0/5600.0
#
# Updates 105, num timesteps 108544, FPS 1783
#  Last 10 training episodes: mean/median reward 3470.0/3400.0, min/max reward 1000.0/5600.0
#
# Updates 106, num timesteps 109568, FPS 1784
#  Last 10 training episodes: mean/median reward 3350.0/3400.0, min/max reward 1000.0/5600.0
#
# Updates 107, num timesteps 110592, FPS 1786
#  Last 10 training episodes: mean/median reward 3350.0/3400.0, min/max reward 1000.0/5600.0
#
# Updates 108, num timesteps 111616, FPS 1787
#  Last 10 training episodes: mean/median reward 3290.0/3300.0, min/max reward 1000.0/5300.0
#
# Updates 109, num timesteps 112640, FPS 1787
#  Last 10 training episodes: mean/median reward 3210.0/3200.0, min/max reward 1000.0/5300.0
#
# Updates 110, num timesteps 113664, FPS 1787
#  Last 10 training episodes: mean/median reward 3200.0/3200.0, min/max reward 1000.0/5300.0
#
# Updates 111, num timesteps 114688, FPS 1788
#  Last 10 training episodes: mean/median reward 3200.0/3200.0, min/max reward 1000.0/5300.0
#
# Updates 112, num timesteps 115712, FPS 1789
#  Last 10 training episodes: mean/median reward 3020.0/3150.0, min/max reward 1000.0/5300.0
#
# Updates 113, num timesteps 116736, FPS 1789
#  Last 10 training episodes: mean/median reward 3020.0/3150.0, min/max reward 1000.0/5300.0
#
# Updates 114, num timesteps 117760, FPS 1788
#  Last 10 training episodes: mean/median reward 3270.0/3200.0, min/max reward 1900.0/5300.0
#
# Updates 115, num timesteps 118784, FPS 1787
#  Last 10 training episodes: mean/median reward 3140.0/3150.0, min/max reward 1900.0/5300.0
#
# Updates 116, num timesteps 119808, FPS 1787
#  Last 10 training episodes: mean/median reward 3140.0/3150.0, min/max reward 1900.0/5300.0
#
# Updates 117, num timesteps 120832, FPS 1788
#  Last 10 training episodes: mean/median reward 3140.0/3150.0, min/max reward 1900.0/5300.0
#
# Updates 118, num timesteps 121856, FPS 1789
#  Last 10 training episodes: mean/median reward 3140.0/3150.0, min/max reward 1900.0/5300.0
#
# Updates 119, num timesteps 122880, FPS 1788
#  Last 10 training episodes: mean/median reward 3050.0/3100.0, min/max reward 1900.0/5300.0
#
# Updates 120, num timesteps 123904, FPS 1789
#  Last 10 training episodes: mean/median reward 3050.0/3100.0, min/max reward 1900.0/5300.0
#
# Updates 121, num timesteps 124928, FPS 1789
#  Last 10 training episodes: mean/median reward 3120.0/3150.0, min/max reward 1900.0/5300.0
#
# Updates 122, num timesteps 125952, FPS 1790
#  Last 10 training episodes: mean/median reward 3230.0/3150.0, min/max reward 2100.0/5300.0
#
# Updates 123, num timesteps 126976, FPS 1788
#  Last 10 training episodes: mean/median reward 3060.0/3100.0, min/max reward 2100.0/4300.0
#
# Updates 124, num timesteps 128000, FPS 1790
#  Last 10 training episodes: mean/median reward 3060.0/3100.0, min/max reward 2100.0/4300.0
#
# Updates 125, num timesteps 129024, FPS 1792
#  Last 10 training episodes: mean/median reward 3060.0/3100.0, min/max reward 2100.0/4300.0
#
# Updates 126, num timesteps 130048, FPS 1792
#  Last 10 training episodes: mean/median reward 3120.0/3150.0, min/max reward 2100.0/4300.0
#
# Updates 127, num timesteps 131072, FPS 1794
#  Last 10 training episodes: mean/median reward 3120.0/3150.0, min/max reward 2100.0/4300.0
#
# Updates 128, num timesteps 132096, FPS 1795
#  Last 10 training episodes: mean/median reward 3120.0/3150.0, min/max reward 2100.0/4300.0
#
# Updates 129, num timesteps 133120, FPS 1793
#  Last 10 training episodes: mean/median reward 3690.0/3350.0, min/max reward 2300.0/7900.0
#
# Updates 130, num timesteps 134144, FPS 1794
#  Last 10 training episodes: mean/median reward 3690.0/3350.0, min/max reward 2300.0/7900.0
#
# Updates 131, num timesteps 135168, FPS 1794
#  Last 10 training episodes: mean/median reward 3660.0/3200.0, min/max reward 2300.0/7900.0
#
# Updates 132, num timesteps 136192, FPS 1796
#  Last 10 training episodes: mean/median reward 3660.0/3200.0, min/max reward 2300.0/7900.0
#
# Updates 133, num timesteps 137216, FPS 1798
#  Last 10 training episodes: mean/median reward 3660.0/3200.0, min/max reward 2300.0/7900.0
#
# Updates 134, num timesteps 138240, FPS 1799
#  Last 10 training episodes: mean/median reward 4020.0/3500.0, min/max reward 2300.0/7900.0
# Updates 135, num timesteps 139264, FPS 1800
#  Last 10 training episodes: mean/median reward 4390.0/3900.0, min/max reward 2400.0/7900.0
#
# Updates 136, num timesteps 140288, FPS 1801
#  Last 10 training episodes: mean/median reward 4390.0/3900.0, min/max reward 2400.0/7900.0
#
# Updates 137, num timesteps 141312, FPS 1802
#  Last 10 training episodes: mean/median reward 4390.0/3900.0, min/max reward 2400.0/7900.0
#
# Updates 138, num timesteps 142336, FPS 1803
#  Last 10 training episodes: mean/median reward 4580.0/4150.0, min/max reward 3000.0/7900.0
#
# Updates 139, num timesteps 143360, FPS 1804
#  Last 10 training episodes: mean/median reward 4830.0/4150.0, min/max reward 3000.0/7900.0
#
# Updates 140, num timesteps 144384, FPS 1806
#  Last 10 training episodes: mean/median reward 4830.0/4150.0, min/max reward 3000.0/7900.0
#
# Updates 141, num timesteps 145408, FPS 1807
#  Last 10 training episodes: mean/median reward 4820.0/4150.0, min/max reward 3000.0/7900.0
#
# Updates 142, num timesteps 146432, FPS 1808
#  Last 10 training episodes: mean/median reward 4590.0/4150.0, min/max reward 3000.0/6800.0
#
# Updates 143, num timesteps 147456, FPS 1810
#  Last 10 training episodes: mean/median reward 4590.0/4150.0, min/max reward 3000.0/6800.0
#
# Updates 144, num timesteps 148480, FPS 1811
#  Last 10 training episodes: mean/median reward 4660.0/4150.0, min/max reward 3000.0/6800.0
#
# Updates 145, num timesteps 149504, FPS 1813
#  Last 10 training episodes: mean/median reward 4660.0/4150.0, min/max reward 3000.0/6800.0
#
# Updates 146, num timesteps 150528, FPS 1813
#  Last 10 training episodes: mean/median reward 4870.0/4800.0, min/max reward 3000.0/6800.0
#
# Updates 147, num timesteps 151552, FPS 1815
#  Last 10 training episodes: mean/median reward 4870.0/4800.0, min/max reward 3000.0/6800.0
#
# Updates 148, num timesteps 152576, FPS 1815
#  Last 10 training episodes: mean/median reward 4980.0/5000.0, min/max reward 3000.0/6800.0
#
# Updates 149, num timesteps 153600, FPS 1816
#  Last 10 training episodes: mean/median reward 4980.0/5000.0, min/max reward 3000.0/6800.0
#
# Updates 150, num timesteps 154624, FPS 1817
#  Last 10 training episodes: mean/median reward 5070.0/5000.0, min/max reward 3000.0/6800.0
#
# Updates 151, num timesteps 155648, FPS 1817
#  Last 10 training episodes: mean/median reward 5110.0/5000.0, min/max reward 3400.0/6800.0
#
# Updates 152, num timesteps 156672, FPS 1818
#  Last 10 training episodes: mean/median reward 5150.0/5000.0, min/max reward 3400.0/6800.0
#
# Updates 153, num timesteps 157696, FPS 1819
#  Last 10 training episodes: mean/median reward 5150.0/5000.0, min/max reward 3400.0/6800.0
#
# Updates 154, num timesteps 158720, FPS 1821
#  Last 10 training episodes: mean/median reward 5150.0/5000.0, min/max reward 3400.0/6800.0
#
# Updates 155, num timesteps 159744, FPS 1822
#  Last 10 training episodes: mean/median reward 5150.0/5000.0, min/max reward 3400.0/6800.0
#
# Updates 156, num timesteps 160768, FPS 1823
#  Last 10 training episodes: mean/median reward 5150.0/5000.0, min/max reward 3400.0/6800.0
#
# Updates 157, num timesteps 161792, FPS 1825
#  Last 10 training episodes: mean/median reward 5150.0/5000.0, min/max reward 3400.0/6800.0
#
# Updates 158, num timesteps 162816, FPS 1826
#  Last 10 training episodes: mean/median reward 5150.0/5000.0, min/max reward 3400.0/6800.0
#
# Updates 159, num timesteps 163840, FPS 1827
#  Last 10 training episodes: mean/median reward 5150.0/5000.0, min/max reward 3400.0/6800.0
#
# Updates 160, num timesteps 164864, FPS 1826
#  Last 10 training episodes: mean/median reward 4710.0/4700.0, min/max reward 2700.0/6700.0
#
# Updates 161, num timesteps 165888, FPS 1826
#  Last 10 training episodes: mean/median reward 4690.0/4700.0, min/max reward 2700.0/6700.0
#
# Updates 162, num timesteps 166912, FPS 1827
#  Last 10 training episodes: mean/median reward 4690.0/4700.0, min/max reward 2700.0/6700.0
#
# Updates 163, num timesteps 167936, FPS 1828
#  Last 10 training episodes: mean/median reward 4770.0/4900.0, min/max reward 2700.0/6700.0
#
# Updates 164, num timesteps 168960, FPS 1829
#  Last 10 training episodes: mean/median reward 4770.0/4900.0, min/max reward 2700.0/6700.0
#
# Updates 165, num timesteps 169984, FPS 1831
#  Last 10 training episodes: mean/median reward 4770.0/4900.0, min/max reward 2700.0/6700.0
#
# Updates 166, num timesteps 171008, FPS 1830
#  Last 10 training episodes: mean/median reward 4300.0/4150.0, min/max reward 2700.0/5700.0
#
# Updates 167, num timesteps 172032, FPS 1832
#  Last 10 training episodes: mean/median reward 4300.0/4150.0, min/max reward 2700.0/5700.0
#
# Updates 168, num timesteps 173056, FPS 1832
#  Last 10 training episodes: mean/median reward 4370.0/4400.0, min/max reward 2700.0/5700.0
#
# Updates 169, num timesteps 174080, FPS 1833
#  Last 10 training episodes: mean/median reward 4370.0/4400.0, min/max reward 2700.0/5700.0
#
# Updates 170, num timesteps 175104, FPS 1835
#  Last 10 training episodes: mean/median reward 4370.0/4400.0, min/max reward 2700.0/5700.0
#
# Updates 171, num timesteps 176128, FPS 1835
#  Last 10 training episodes: mean/median reward 4090.0/3850.0, min/max reward 1900.0/5700.0
#
# Updates 172, num timesteps 177152, FPS 1837
#  Last 10 training episodes: mean/median reward 4090.0/3850.0, min/max reward 1900.0/5700.0
#
# Updates 173, num timesteps 178176, FPS 1837
#  Last 10 training episodes: mean/median reward 3920.0/3800.0, min/max reward 1900.0/5700.0
#
# Updates 174, num timesteps 179200, FPS 1838
#  Last 10 training episodes: mean/median reward 4050.0/4050.0, min/max reward 1900.0/5700.0
#
# Updates 175, num timesteps 180224, FPS 1839
#  Last 10 training episodes: mean/median reward 4220.0/4500.0, min/max reward 1900.0/5700.0
#
# Updates 176, num timesteps 181248, FPS 1839
#  Last 10 training episodes: mean/median reward 4280.0/4500.0, min/max reward 1900.0/5900.0
#
# Updates 177, num timesteps 182272, FPS 1840
#  Last 10 training episodes: mean/median reward 4280.0/4500.0, min/max reward 1900.0/5900.0
#
# Updates 178, num timesteps 183296, FPS 1840
#  Last 10 training episodes: mean/median reward 4260.0/4500.0, min/max reward 1900.0/5900.0
#
# Updates 179, num timesteps 184320, FPS 1842
#  Last 10 training episodes: mean/median reward 4260.0/4500.0, min/max reward 1900.0/5900.0
#
# Updates 180, num timesteps 185344, FPS 1843
#  Last 10 training episodes: mean/median reward 4260.0/4500.0, min/max reward 1900.0/5900.0
#
# Updates 181, num timesteps 186368, FPS 1843
#  Last 10 training episodes: mean/median reward 4260.0/4500.0, min/max reward 1900.0/5900.0
#
# Updates 182, num timesteps 187392, FPS 1844
#  Last 10 training episodes: mean/median reward 4260.0/4500.0, min/max reward 1900.0/5900.0
#
# Updates 183, num timesteps 188416, FPS 1844
#  Last 10 training episodes: mean/median reward 4470.0/5000.0, min/max reward 1900.0/5900.0
#
# Updates 184, num timesteps 189440, FPS 1845
#  Last 10 training episodes: mean/median reward 4470.0/5000.0, min/max reward 1900.0/5900.0
#
# Updates 185, num timesteps 190464, FPS 1846
#  Last 10 training episodes: mean/median reward 4530.0/5000.0, min/max reward 1900.0/5900.0
#
# Updates 186, num timesteps 191488, FPS 1844
#  Last 10 training episodes: mean/median reward 4400.0/4900.0, min/max reward 2400.0/5900.0
#
# Updates 187, num timesteps 192512, FPS 1845
#  Last 10 training episodes: mean/median reward 4280.0/4400.0, min/max reward 2400.0/5900.0
#
# Updates 188, num timesteps 193536, FPS 1845
#  Last 10 training episodes: mean/median reward 4280.0/4400.0, min/max reward 2400.0/5900.0
#
# Updates 189, num timesteps 194560, FPS 1846
#  Last 10 training episodes: mean/median reward 4280.0/4400.0, min/max reward 2400.0/5900.0
#
# Updates 190, num timesteps 195584, FPS 1847
#  Last 10 training episodes: mean/median reward 4280.0/4400.0, min/max reward 2400.0/5900.0
#
# Updates 191, num timesteps 196608, FPS 1848
#  Last 10 training episodes: mean/median reward 4280.0/4400.0, min/max reward 2400.0/5900.0
#
# Updates 192, num timesteps 197632, FPS 1849
#  Last 10 training episodes: mean/median reward 4280.0/4400.0, min/max reward 2400.0/5900.0
#
# Updates 193, num timesteps 198656, FPS 1850
#  Last 10 training episodes: mean/median reward 4280.0/4400.0, min/max reward 2400.0/5900.0
#
# Updates 194, num timesteps 199680, FPS 1850
#  Last 10 training episodes: mean/median reward 4280.0/4400.0, min/max reward 2400.0/5900.0
# Updates 195, num timesteps 200704, FPS 1851
#  Last 10 training episodes: mean/median reward 4280.0/4400.0, min/max reward 2400.0/5900.0
#
# Updates 196, num timesteps 201728, FPS 1851
#  Last 10 training episodes: mean/median reward 4300.0/4400.0, min/max reward 2400.0/5900.0
#
# Updates 197, num timesteps 202752, FPS 1852
#  Last 10 training episodes: mean/median reward 4250.0/4400.0, min/max reward 2400.0/5700.0
#
# Updates 198, num timesteps 203776, FPS 1852
#  Last 10 training episodes: mean/median reward 3900.0/3700.0, min/max reward 2400.0/6400.0
#
# Updates 199, num timesteps 204800, FPS 1853
#  Last 10 training episodes: mean/median reward 3900.0/3700.0, min/max reward 2400.0/6400.0
#
# Updates 200, num timesteps 205824, FPS 1853
#  Last 10 training episodes: mean/median reward 3900.0/3700.0, min/max reward 2400.0/6400.0
#
# Updates 201, num timesteps 206848, FPS 1854
#  Last 10 training episodes: mean/median reward 3950.0/3700.0, min/max reward 2400.0/6400.0
#
# Updates 202, num timesteps 207872, FPS 1854
#  Last 10 training episodes: mean/median reward 4510.0/3950.0, min/max reward 2400.0/8900.0
#
# Updates 203, num timesteps 208896, FPS 1855
#  Last 10 training episodes: mean/median reward 4510.0/3950.0, min/max reward 2400.0/8900.0
#
# Updates 204, num timesteps 209920, FPS 1856
#  Last 10 training episodes: mean/median reward 4540.0/4100.0, min/max reward 2400.0/8900.0
#
# Updates 205, num timesteps 210944, FPS 1856
#  Last 10 training episodes: mean/median reward 4540.0/4100.0, min/max reward 2400.0/8900.0
#
# Updates 206, num timesteps 211968, FPS 1857
#  Last 10 training episodes: mean/median reward 4540.0/4100.0, min/max reward 2400.0/8900.0
#
# Updates 207, num timesteps 212992, FPS 1857
#  Last 10 training episodes: mean/median reward 4940.0/4650.0, min/max reward 2400.0/8900.0
#
# Updates 208, num timesteps 214016, FPS 1858
#  Last 10 training episodes: mean/median reward 4940.0/4650.0, min/max reward 2400.0/8900.0
#
# Updates 209, num timesteps 215040, FPS 1859
#  Last 10 training episodes: mean/median reward 4940.0/4650.0, min/max reward 2400.0/8900.0
#
# Updates 210, num timesteps 216064, FPS 1859
#  Last 10 training episodes: mean/median reward 4870.0/4400.0, min/max reward 2400.0/8900.0
#
# Updates 211, num timesteps 217088, FPS 1860
#  Last 10 training episodes: mean/median reward 4870.0/4400.0, min/max reward 2400.0/8900.0
#
# Updates 212, num timesteps 218112, FPS 1861
#  Last 10 training episodes: mean/median reward 4870.0/4400.0, min/max reward 2400.0/8900.0
#
# Updates 213, num timesteps 219136, FPS 1862
#  Last 10 training episodes: mean/median reward 5250.0/4950.0, min/max reward 2400.0/8900.0
#
# Updates 214, num timesteps 220160, FPS 1862
#  Last 10 training episodes: mean/median reward 5250.0/4950.0, min/max reward 2400.0/8900.0
#
# Updates 215, num timesteps 221184, FPS 1863
#  Last 10 training episodes: mean/median reward 5250.0/4950.0, min/max reward 2400.0/8900.0
#
# Updates 216, num timesteps 222208, FPS 1864
#  Last 10 training episodes: mean/median reward 5740.0/5800.0, min/max reward 2400.0/8900.0
#
# Updates 217, num timesteps 223232, FPS 1864
#  Last 10 training episodes: mean/median reward 5740.0/5800.0, min/max reward 2400.0/8900.0
#
# Updates 218, num timesteps 224256, FPS 1865
#  Last 10 training episodes: mean/median reward 5780.0/5800.0, min/max reward 2400.0/8900.0
#
# Updates 219, num timesteps 225280, FPS 1865
#  Last 10 training episodes: mean/median reward 6060.0/6600.0, min/max reward 2400.0/8900.0
#
# Updates 220, num timesteps 226304, FPS 1865
#  Last 10 training episodes: mean/median reward 5530.0/5550.0, min/max reward 2400.0/8500.0
#
# Updates 221, num timesteps 227328, FPS 1866
#  Last 10 training episodes: mean/median reward 5530.0/5550.0, min/max reward 2400.0/8500.0
#
# Updates 222, num timesteps 228352, FPS 1867
#  Last 10 training episodes: mean/median reward 5530.0/5550.0, min/max reward 2400.0/8500.0
#
# Updates 223, num timesteps 229376, FPS 1867
#  Last 10 training episodes: mean/median reward 5520.0/5550.0, min/max reward 2400.0/8500.0
#
# Updates 224, num timesteps 230400, FPS 1867
#  Last 10 training episodes: mean/median reward 5480.0/5450.0, min/max reward 2800.0/8500.0
#
# Updates 225, num timesteps 231424, FPS 1868
#  Last 10 training episodes: mean/median reward 5480.0/5450.0, min/max reward 2800.0/8500.0
#
# Updates 226, num timesteps 232448, FPS 1867
#  Last 10 training episodes: mean/median reward 5790.0/6000.0, min/max reward 3600.0/8500.0
#
# Updates 227, num timesteps 233472, FPS 1867
#  Last 10 training episodes: mean/median reward 5790.0/6000.0, min/max reward 3600.0/8500.0
#
# Updates 228, num timesteps 234496, FPS 1868
#  Last 10 training episodes: mean/median reward 5790.0/6000.0, min/max reward 3600.0/8500.0
#
# Updates 229, num timesteps 235520, FPS 1868
#  Last 10 training episodes: mean/median reward 5790.0/6000.0, min/max reward 3600.0/8500.0
#
# Updates 230, num timesteps 236544, FPS 1869
#  Last 10 training episodes: mean/median reward 5790.0/6000.0, min/max reward 3600.0/8500.0
#
# Updates 231, num timesteps 237568, FPS 1870
#  Last 10 training episodes: mean/median reward 5790.0/6000.0, min/max reward 3600.0/8500.0
#
# Updates 232, num timesteps 238592, FPS 1870
#  Last 10 training episodes: mean/median reward 5450.0/5300.0, min/max reward 3600.0/8000.0
#
# Updates 233, num timesteps 239616, FPS 1870
#  Last 10 training episodes: mean/median reward 5580.0/5300.0, min/max reward 3600.0/8100.0
#
# Updates 234, num timesteps 240640, FPS 1871
#  Last 10 training episodes: mean/median reward 5580.0/5300.0, min/max reward 3600.0/8100.0
#
# Updates 235, num timesteps 241664, FPS 1871
#  Last 10 training episodes: mean/median reward 5420.0/5300.0, min/max reward 3600.0/8100.0
#
# Updates 236, num timesteps 242688, FPS 1871
#  Last 10 training episodes: mean/median reward 5420.0/5300.0, min/max reward 3600.0/8100.0
#
# Updates 237, num timesteps 243712, FPS 1872
#  Last 10 training episodes: mean/median reward 5420.0/5300.0, min/max reward 3600.0/8100.0
#
# Updates 238, num timesteps 244736, FPS 1873
#  Last 10 training episodes: mean/median reward 5420.0/5300.0, min/max reward 3600.0/8100.0
#
# Updates 239, num timesteps 245760, FPS 1873
#  Last 10 training episodes: mean/median reward 5420.0/5300.0, min/max reward 3600.0/8100.0
#
# Updates 240, num timesteps 246784, FPS 1871
#  Last 10 training episodes: mean/median reward 5630.0/5750.0, min/max reward 3800.0/8100.0
#
# Updates 241, num timesteps 247808, FPS 1871
#  Last 10 training episodes: mean/median reward 5490.0/5350.0, min/max reward 3800.0/8100.0
#
# Updates 242, num timesteps 248832, FPS 1871
#  Last 10 training episodes: mean/median reward 5780.0/5750.0, min/max reward 3800.0/8100.0
#
# Updates 243, num timesteps 249856, FPS 1872
#  Last 10 training episodes: mean/median reward 5780.0/5750.0, min/max reward 3800.0/8100.0
#
# Updates 244, num timesteps 250880, FPS 1873
#  Last 10 training episodes: mean/median reward 5780.0/5750.0, min/max reward 3800.0/8100.0
#
# Updates 245, num timesteps 251904, FPS 1873
#  Last 10 training episodes: mean/median reward 5780.0/5750.0, min/max reward 3800.0/8100.0
#
# Updates 246, num timesteps 252928, FPS 1873
#  Last 10 training episodes: mean/median reward 5640.0/5750.0, min/max reward 3800.0/8100.0
#
# Updates 247, num timesteps 253952, FPS 1873
#  Last 10 training episodes: mean/median reward 5640.0/5750.0, min/max reward 3800.0/8100.0
#
# Updates 248, num timesteps 254976, FPS 1872
#  Last 10 training episodes: mean/median reward 5640.0/5750.0, min/max reward 3800.0/8100.0
#
# Updates 249, num timesteps 256000, FPS 1872
#  Last 10 training episodes: mean/median reward 5640.0/5750.0, min/max reward 3800.0/8100.0
#
# Updates 250, num timesteps 257024, FPS 1873
#  Last 10 training episodes: mean/median reward 5640.0/5750.0, min/max reward 3800.0/8100.0
#
# Updates 251, num timesteps 258048, FPS 1873
#  Last 10 training episodes: mean/median reward 5320.0/5350.0, min/max reward 3800.0/6900.0
#
# Updates 252, num timesteps 259072, FPS 1873
#  Last 10 training episodes: mean/median reward 5210.0/4850.0, min/max reward 3800.0/6900.0
#
# Updates 253, num timesteps 260096, FPS 1874
#  Last 10 training episodes: mean/median reward 5210.0/4850.0, min/max reward 3800.0/6900.0
#
# Updates 254, num timesteps 261120, FPS 1874
#  Last 10 training episodes: mean/median reward 5240.0/5000.0, min/max reward 3800.0/6900.0
# Updates 255, num timesteps 262144, FPS 1873
#  Last 10 training episodes: mean/median reward 5150.0/5000.0, min/max reward 2900.0/6900.0
#
# Updates 256, num timesteps 263168, FPS 1872
#  Last 10 training episodes: mean/median reward 5150.0/5000.0, min/max reward 2900.0/6900.0
#
# Updates 257, num timesteps 264192, FPS 1872
#  Last 10 training episodes: mean/median reward 4870.0/4650.0, min/max reward 2900.0/6900.0
#
# Updates 258, num timesteps 265216, FPS 1872
#  Last 10 training episodes: mean/median reward 4870.0/4650.0, min/max reward 2900.0/6900.0
#
# Updates 259, num timesteps 266240, FPS 1871
#  Last 10 training episodes: mean/median reward 4870.0/4650.0, min/max reward 2900.0/6900.0
#
# Updates 260, num timesteps 267264, FPS 1871
#  Last 10 training episodes: mean/median reward 4870.0/4650.0, min/max reward 2900.0/6900.0
#
# Updates 261, num timesteps 268288, FPS 1871
#  Last 10 training episodes: mean/median reward 4870.0/4650.0, min/max reward 2900.0/6900.0
#
# Updates 262, num timesteps 269312, FPS 1871
#  Last 10 training episodes: mean/median reward 5010.0/4650.0, min/max reward 2900.0/7400.0
#
# Updates 263, num timesteps 270336, FPS 1872
#  Last 10 training episodes: mean/median reward 5010.0/4650.0, min/max reward 2900.0/7400.0
#
# Updates 264, num timesteps 271360, FPS 1872
#  Last 10 training episodes: mean/median reward 4910.0/4650.0, min/max reward 2900.0/7400.0
#
# Updates 265, num timesteps 272384, FPS 1872
#  Last 10 training episodes: mean/median reward 4920.0/4700.0, min/max reward 2900.0/7400.0
#
# Updates 266, num timesteps 273408, FPS 1873
#  Last 10 training episodes: mean/median reward 4920.0/4700.0, min/max reward 2900.0/7400.0
#
# Updates 267, num timesteps 274432, FPS 1874
#  Last 10 training episodes: mean/median reward 4920.0/4700.0, min/max reward 2900.0/7400.0
#
# Updates 268, num timesteps 275456, FPS 1875
#  Last 10 training episodes: mean/median reward 4920.0/4700.0, min/max reward 2900.0/7400.0
#
# Updates 269, num timesteps 276480, FPS 1875
#  Last 10 training episodes: mean/median reward 4920.0/4700.0, min/max reward 2900.0/7400.0
#
# Updates 270, num timesteps 277504, FPS 1875
#  Last 10 training episodes: mean/median reward 4650.0/4500.0, min/max reward 2900.0/7400.0
#
# Updates 271, num timesteps 278528, FPS 1875
#  Last 10 training episodes: mean/median reward 4800.0/5000.0, min/max reward 2900.0/7400.0
#
# Updates 272, num timesteps 279552, FPS 1875
#  Last 10 training episodes: mean/median reward 4800.0/5000.0, min/max reward 2900.0/7400.0
#
# Updates 273, num timesteps 280576, FPS 1876
#  Last 10 training episodes: mean/median reward 4800.0/5000.0, min/max reward 2900.0/7400.0
#
# Updates 274, num timesteps 281600, FPS 1876
#  Last 10 training episodes: mean/median reward 4680.0/4500.0, min/max reward 2800.0/7400.0
#
# Updates 275, num timesteps 282624, FPS 1876
#  Last 10 training episodes: mean/median reward 4680.0/4500.0, min/max reward 2800.0/7400.0
#
# Updates 276, num timesteps 283648, FPS 1877
#  Last 10 training episodes: mean/median reward 5050.0/5000.0, min/max reward 2800.0/7600.0
#
# Updates 277, num timesteps 284672, FPS 1876
#  Last 10 training episodes: mean/median reward 4910.0/4500.0, min/max reward 2800.0/8500.0
#
# Updates 278, num timesteps 285696, FPS 1876
#  Last 10 training episodes: mean/median reward 4910.0/4500.0, min/max reward 2800.0/8500.0
#
# Updates 279, num timesteps 286720, FPS 1877
#  Last 10 training episodes: mean/median reward 4910.0/4500.0, min/max reward 2800.0/8500.0
#
# Updates 280, num timesteps 287744, FPS 1876
#  Last 10 training episodes: mean/median reward 5060.0/5000.0, min/max reward 2800.0/8500.0
#
# Updates 281, num timesteps 288768, FPS 1877
#  Last 10 training episodes: mean/median reward 5060.0/5000.0, min/max reward 2800.0/8500.0
#
# Updates 282, num timesteps 289792, FPS 1878
#  Last 10 training episodes: mean/median reward 5060.0/5000.0, min/max reward 2800.0/8500.0
#
# Updates 283, num timesteps 290816, FPS 1877
#  Last 10 training episodes: mean/median reward 5440.0/5050.0, min/max reward 2800.0/9000.0
#
# Updates 284, num timesteps 291840, FPS 1877
#  Last 10 training episodes: mean/median reward 5440.0/5050.0, min/max reward 2800.0/9000.0
#
# Updates 285, num timesteps 292864, FPS 1878
#  Last 10 training episodes: mean/median reward 5290.0/4500.0, min/max reward 2800.0/9000.0
#
# Updates 286, num timesteps 293888, FPS 1878
#  Last 10 training episodes: mean/median reward 5290.0/4500.0, min/max reward 2800.0/9000.0
#
# Updates 287, num timesteps 294912, FPS 1879
#  Last 10 training episodes: mean/median reward 5290.0/4500.0, min/max reward 2800.0/9000.0
#
# Updates 288, num timesteps 295936, FPS 1878
#  Last 10 training episodes: mean/median reward 5570.0/5250.0, min/max reward 2800.0/9000.0
#
# Updates 289, num timesteps 296960, FPS 1879
#  Last 10 training episodes: mean/median reward 5570.0/5250.0, min/max reward 2800.0/9000.0
#
# Updates 290, num timesteps 297984, FPS 1879
#  Last 10 training episodes: mean/median reward 5570.0/5250.0, min/max reward 2800.0/9000.0
#
# Updates 291, num timesteps 299008, FPS 1879
#  Last 10 training episodes: mean/median reward 5940.0/6100.0, min/max reward 3100.0/9000.0
#
# Updates 292, num timesteps 300032, FPS 1879
#  Last 10 training episodes: mean/median reward 5940.0/6100.0, min/max reward 3100.0/9000.0
#
# Updates 293, num timesteps 301056, FPS 1880
#  Last 10 training episodes: mean/median reward 5940.0/6100.0, min/max reward 3100.0/9000.0
#
# Updates 294, num timesteps 302080, FPS 1880
#  Last 10 training episodes: mean/median reward 5860.0/6100.0, min/max reward 2300.0/9000.0
#
# Updates 295, num timesteps 303104, FPS 1880
#  Last 10 training episodes: mean/median reward 5860.0/6100.0, min/max reward 2300.0/9000.0
#
# Updates 296, num timesteps 304128, FPS 1881
#  Last 10 training episodes: mean/median reward 5910.0/6100.0, min/max reward 2300.0/9000.0
#
# Updates 297, num timesteps 305152, FPS 1881
#  Last 10 training episodes: mean/median reward 5910.0/6100.0, min/max reward 2300.0/9000.0
#
# Updates 298, num timesteps 306176, FPS 1880
#  Last 10 training episodes: mean/median reward 5510.0/5500.0, min/max reward 2300.0/9000.0
#
# Updates 299, num timesteps 307200, FPS 1881
#  Last 10 training episodes: mean/median reward 5510.0/5500.0, min/max reward 2300.0/9000.0
#
# Updates 300, num timesteps 308224, FPS 1881
#  Last 10 training episodes: mean/median reward 5510.0/5500.0, min/max reward 2300.0/9000.0
#
# Updates 301, num timesteps 309248, FPS 1881
#  Last 10 training episodes: mean/median reward 5370.0/5250.0, min/max reward 2300.0/9000.0
#
# Updates 302, num timesteps 310272, FPS 1881
#  Last 10 training episodes: mean/median reward 4990.0/5200.0, min/max reward 2300.0/7600.0
#
# Updates 303, num timesteps 311296, FPS 1881
#  Last 10 training episodes: mean/median reward 5400.0/5250.0, min/max reward 2300.0/7900.0
#
# Updates 304, num timesteps 312320, FPS 1881
#  Last 10 training episodes: mean/median reward 5400.0/5250.0, min/max reward 2300.0/7900.0
#
# Updates 305, num timesteps 313344, FPS 1882
#  Last 10 training episodes: mean/median reward 5400.0/5250.0, min/max reward 2300.0/7900.0
#
# Updates 306, num timesteps 314368, FPS 1882
#  Last 10 training episodes: mean/median reward 5400.0/5250.0, min/max reward 2300.0/7900.0
#
# Updates 307, num timesteps 315392, FPS 1882
#  Last 10 training episodes: mean/median reward 4870.0/5200.0, min/max reward 1700.0/7900.0
#
# Updates 308, num timesteps 316416, FPS 1882
#  Last 10 training episodes: mean/median reward 5600.0/5250.0, min/max reward 1700.0/10200.0
#
# Updates 309, num timesteps 317440, FPS 1883
#  Last 10 training episodes: mean/median reward 5600.0/5250.0, min/max reward 1700.0/10200.0
#
# Updates 310, num timesteps 318464, FPS 1883
#  Last 10 training episodes: mean/median reward 5600.0/5250.0, min/max reward 1700.0/10200.0
#
# Updates 311, num timesteps 319488, FPS 1882
#  Last 10 training episodes: mean/median reward 5650.0/5500.0, min/max reward 1700.0/10200.0
#
# Updates 312, num timesteps 320512, FPS 1882
#  Last 10 training episodes: mean/median reward 5410.0/5500.0, min/max reward 1700.0/10200.0
#
# Updates 313, num timesteps 321536, FPS 1883
#  Last 10 training episodes: mean/median reward 5410.0/5500.0, min/max reward 1700.0/10200.0
#
# Updates 314, num timesteps 322560, FPS 1883
#  Last 10 training episodes: mean/median reward 5410.0/5500.0, min/max reward 1700.0/10200.0
# Updates 315, num timesteps 323584, FPS 1883
#  Last 10 training episodes: mean/median reward 5620.0/5850.0, min/max reward 1700.0/10200.0
#
# Updates 316, num timesteps 324608, FPS 1883
#  Last 10 training episodes: mean/median reward 5620.0/5850.0, min/max reward 1700.0/10200.0
#
# Updates 317, num timesteps 325632, FPS 1884
#  Last 10 training episodes: mean/median reward 5620.0/5850.0, min/max reward 1700.0/10200.0
#
# Updates 318, num timesteps 326656, FPS 1884
#  Last 10 training episodes: mean/median reward 5620.0/5850.0, min/max reward 1700.0/10200.0
#
# Updates 319, num timesteps 327680, FPS 1883
#  Last 10 training episodes: mean/median reward 5400.0/5600.0, min/max reward 2000.0/10200.0
#
# Updates 320, num timesteps 328704, FPS 1883
#  Last 10 training episodes: mean/median reward 4800.0/4800.0, min/max reward 2000.0/8000.0
#
# Updates 321, num timesteps 329728, FPS 1882
#  Last 10 training episodes: mean/median reward 4800.0/4800.0, min/max reward 2000.0/8000.0
#
# Updates 322, num timesteps 330752, FPS 1882
#  Last 10 training episodes: mean/median reward 4800.0/4800.0, min/max reward 2000.0/8000.0
#
# Updates 323, num timesteps 331776, FPS 1882
#  Last 10 training episodes: mean/median reward 4800.0/4800.0, min/max reward 2000.0/8000.0
#
# Updates 324, num timesteps 332800, FPS 1882
#  Last 10 training episodes: mean/median reward 4620.0/4150.0, min/max reward 2000.0/8000.0
#
# Updates 325, num timesteps 333824, FPS 1882
#  Last 10 training episodes: mean/median reward 4620.0/4150.0, min/max reward 2000.0/8000.0
#
# Updates 326, num timesteps 334848, FPS 1882
#  Last 10 training episodes: mean/median reward 4550.0/4150.0, min/max reward 2000.0/8000.0
#
# Updates 327, num timesteps 335872, FPS 1882
#  Last 10 training episodes: mean/median reward 4260.0/3850.0, min/max reward 2000.0/8000.0
#
# Updates 328, num timesteps 336896, FPS 1881
#  Last 10 training episodes: mean/median reward 4520.0/4150.0, min/max reward 2000.0/8000.0
#
# Updates 329, num timesteps 337920, FPS 1882
#  Last 10 training episodes: mean/median reward 4520.0/4150.0, min/max reward 2000.0/8000.0
#
# Updates 330, num timesteps 338944, FPS 1881
#  Last 10 training episodes: mean/median reward 4590.0/4150.0, min/max reward 2000.0/8000.0
#
# Updates 331, num timesteps 339968, FPS 1882
#  Last 10 training episodes: mean/median reward 4590.0/4150.0, min/max reward 2000.0/8000.0
#
# Updates 332, num timesteps 340992, FPS 1882
#  Last 10 training episodes: mean/median reward 4590.0/4150.0, min/max reward 2000.0/8000.0
#
# Updates 333, num timesteps 342016, FPS 1883
#  Last 10 training episodes: mean/median reward 4590.0/4150.0, min/max reward 2000.0/8000.0
#
# Updates 334, num timesteps 343040, FPS 1883
#  Last 10 training episodes: mean/median reward 4830.0/4500.0, min/max reward 2000.0/8000.0
#
# Updates 335, num timesteps 344064, FPS 1883
#  Last 10 training episodes: mean/median reward 4830.0/4500.0, min/max reward 2000.0/8000.0
#
# Updates 336, num timesteps 345088, FPS 1883
#  Last 10 training episodes: mean/median reward 4610.0/4500.0, min/max reward 2000.0/6900.0
#
# Updates 337, num timesteps 346112, FPS 1882
#  Last 10 training episodes: mean/median reward 5010.0/5000.0, min/max reward 2900.0/6900.0
#
# Updates 338, num timesteps 347136, FPS 1882
#  Last 10 training episodes: mean/median reward 5210.0/5500.0, min/max reward 2900.0/6900.0
#
# Updates 339, num timesteps 348160, FPS 1883
#  Last 10 training episodes: mean/median reward 5210.0/5500.0, min/max reward 2900.0/6900.0
#
# Updates 340, num timesteps 349184, FPS 1883
#  Last 10 training episodes: mean/median reward 5210.0/5500.0, min/max reward 2900.0/6900.0
#
# Updates 341, num timesteps 350208, FPS 1884
#  Last 10 training episodes: mean/median reward 5210.0/5500.0, min/max reward 2900.0/6900.0
#
# Updates 342, num timesteps 351232, FPS 1884
#  Last 10 training episodes: mean/median reward 5050.0/5250.0, min/max reward 2900.0/6800.0
#
# Updates 343, num timesteps 352256, FPS 1884
#  Last 10 training episodes: mean/median reward 5050.0/5250.0, min/max reward 2900.0/6800.0
#
# Updates 344, num timesteps 353280, FPS 1884
#  Last 10 training episodes: mean/median reward 5190.0/5250.0, min/max reward 3600.0/6800.0
#
# Updates 345, num timesteps 354304, FPS 1884
#  Last 10 training episodes: mean/median reward 5280.0/5500.0, min/max reward 3600.0/6800.0
#
# Updates 346, num timesteps 355328, FPS 1884
#  Last 10 training episodes: mean/median reward 5280.0/5500.0, min/max reward 3600.0/6800.0
#
# Updates 347, num timesteps 356352, FPS 1884
#  Last 10 training episodes: mean/median reward 5220.0/5500.0, min/max reward 3400.0/6800.0
#
# Updates 348, num timesteps 357376, FPS 1884
#  Last 10 training episodes: mean/median reward 5220.0/5500.0, min/max reward 3400.0/6800.0
#
# Updates 349, num timesteps 358400, FPS 1885
#  Last 10 training episodes: mean/median reward 5220.0/5500.0, min/max reward 3400.0/6800.0
#
# Updates 350, num timesteps 359424, FPS 1885
#  Last 10 training episodes: mean/median reward 5220.0/5500.0, min/max reward 3400.0/6800.0
#
# Updates 351, num timesteps 360448, FPS 1885
#  Last 10 training episodes: mean/median reward 5220.0/5500.0, min/max reward 3400.0/6800.0
#
# Updates 352, num timesteps 361472, FPS 1886
#  Last 10 training episodes: mean/median reward 5220.0/5500.0, min/max reward 3400.0/6800.0
#
# Updates 353, num timesteps 362496, FPS 1885
#  Last 10 training episodes: mean/median reward 5260.0/5250.0, min/max reward 3400.0/8000.0
#
# Updates 354, num timesteps 363520, FPS 1885
#  Last 10 training episodes: mean/median reward 5260.0/5250.0, min/max reward 3400.0/8000.0
#
# Updates 355, num timesteps 364544, FPS 1885
#  Last 10 training episodes: mean/median reward 5260.0/5250.0, min/max reward 3400.0/8000.0
#
# Updates 356, num timesteps 365568, FPS 1885
#  Last 10 training episodes: mean/median reward 5260.0/5250.0, min/max reward 3400.0/8000.0
#
# Updates 357, num timesteps 366592, FPS 1886
#  Last 10 training episodes: mean/median reward 5260.0/5250.0, min/max reward 3400.0/8000.0
#
# Updates 358, num timesteps 367616, FPS 1886
#  Last 10 training episodes: mean/median reward 5720.0/5500.0, min/max reward 3400.0/8200.0
#
# Updates 359, num timesteps 368640, FPS 1885
#  Last 10 training episodes: mean/median reward 5870.0/5900.0, min/max reward 3400.0/8200.0
#
# Updates 360, num timesteps 369664, FPS 1885
#  Last 10 training episodes: mean/median reward 5890.0/5900.0, min/max reward 3400.0/8200.0
#
# Updates 361, num timesteps 370688, FPS 1886
#  Last 10 training episodes: mean/median reward 5890.0/5900.0, min/max reward 3400.0/8200.0
#
# Updates 362, num timesteps 371712, FPS 1886
#  Last 10 training episodes: mean/median reward 5890.0/5900.0, min/max reward 3400.0/8200.0
#
# Updates 363, num timesteps 372736, FPS 1886
#  Last 10 training episodes: mean/median reward 5710.0/5900.0, min/max reward 3400.0/8200.0
#
# Updates 364, num timesteps 373760, FPS 1885
# ...
#
# Updates 9652, num timesteps 9884672, FPS 1907
#  Last 10 training episodes: mean/median reward 12090.0/11900.0, min/max reward 5400.0/19200.0
#
# Updates 9653, num timesteps 9885696, FPS 1907
#  Last 10 training episodes: mean/median reward 11820.0/11300.0, min/max reward 5400.0/19200.0
#
# Updates 9654, num timesteps 9886720, FPS 1907
#  Last 10 training episodes: mean/median reward 11820.0/11300.0, min/max reward 5400.0/19200.0
#
# Updates 9655, num timesteps 9887744, FPS 1907
#  Last 10 training episodes: mean/median reward 11530.0/10700.0, min/max reward 5400.0/19200.0
#
# Updates 9656, num timesteps 9888768, FPS 1907
#  Last 10 training episodes: mean/median reward 11390.0/10700.0, min/max reward 5400.0/19200.0
#
# Updates 9657, num timesteps 9889792, FPS 1907
#  Last 10 training episodes: mean/median reward 11390.0/10700.0, min/max reward 5400.0/19200.0
#
# Updates 9658, num timesteps 9890816, FPS 1907
#  Last 10 training episodes: mean/median reward 10410.0/10250.0, min/max reward 5400.0/14000.0
#
# Updates 9659, num timesteps 9891840, FPS 1907
#  Last 10 training episodes: mean/median reward 10710.0/10700.0, min/max reward 5400.0/14000.0
#
# Updates 9660, num timesteps 9892864, FPS 1907
#  Last 10 training episodes: mean/median reward 10710.0/10700.0, min/max reward 5400.0/14000.0
#
# Updates 9661, num timesteps 9893888, FPS 1907
#  Last 10 training episodes: mean/median reward 10660.0/10450.0, min/max reward 5400.0/14000.0
#
# Updates 9662, num timesteps 9894912, FPS 1907
#  Last 10 training episodes: mean/median reward 10660.0/10450.0, min/max reward 5400.0/14000.0
#
# Updates 9663, num timesteps 9895936, FPS 1907
#  Last 10 training episodes: mean/median reward 10660.0/10450.0, min/max reward 5400.0/14000.0
#
# Updates 9664, num timesteps 9896960, FPS 1907
#  Last 10 training episodes: mean/median reward 10780.0/10450.0, min/max reward 5400.0/14000.0
#
# Updates 9665, num timesteps 9897984, FPS 1907
#  Last 10 training episodes: mean/median reward 10780.0/10450.0, min/max reward 5400.0/14000.0
# Updates 9666, num timesteps 9899008, FPS 1907
#  Last 10 training episodes: mean/median reward 11080.0/10450.0, min/max reward 8400.0/14000.0
#
# Updates 9667, num timesteps 9900032, FPS 1907
#  Last 10 training episodes: mean/median reward 11080.0/10450.0, min/max reward 8400.0/14000.0
#
# Updates 9668, num timesteps 9901056, FPS 1907
#  Last 10 training episodes: mean/median reward 11140.0/10750.0, min/max reward 8400.0/14000.0
#
# Updates 9669, num timesteps 9902080, FPS 1907
#  Last 10 training episodes: mean/median reward 11140.0/10750.0, min/max reward 8400.0/14000.0
#
# Updates 9670, num timesteps 9903104, FPS 1907
#  Last 10 training episodes: mean/median reward 11140.0/10750.0, min/max reward 8400.0/14000.0
#
# Updates 9671, num timesteps 9904128, FPS 1907
#  Last 10 training episodes: mean/median reward 11570.0/11650.0, min/max reward 8400.0/14000.0
#
# Updates 9672, num timesteps 9905152, FPS 1907
#  Last 10 training episodes: mean/median reward 11570.0/11650.0, min/max reward 8400.0/14000.0
#
# Updates 9673, num timesteps 9906176, FPS 1907
#  Last 10 training episodes: mean/median reward 11570.0/11650.0, min/max reward 8400.0/14000.0
#
# Updates 9674, num timesteps 9907200, FPS 1907
#  Last 10 training episodes: mean/median reward 11570.0/11650.0, min/max reward 8400.0/14000.0
#
# Updates 9675, num timesteps 9908224, FPS 1907
#  Last 10 training episodes: mean/median reward 11420.0/11450.0, min/max reward 8400.0/13700.0
#
# Updates 9676, num timesteps 9909248, FPS 1907
#  Last 10 training episodes: mean/median reward 11420.0/11450.0, min/max reward 8400.0/13700.0
#
# Updates 9677, num timesteps 9910272, FPS 1907
#  Last 10 training episodes: mean/median reward 11420.0/11450.0, min/max reward 8400.0/13700.0
#
# Updates 9678, num timesteps 9911296, FPS 1907
#  Last 10 training episodes: mean/median reward 11420.0/11450.0, min/max reward 8400.0/13700.0
#
# Updates 9679, num timesteps 9912320, FPS 1907
#  Last 10 training episodes: mean/median reward 11580.0/12050.0, min/max reward 8400.0/13700.0
#
# Updates 9680, num timesteps 9913344, FPS 1907
#  Last 10 training episodes: mean/median reward 11360.0/11450.0, min/max reward 8400.0/13700.0
#
# Updates 9681, num timesteps 9914368, FPS 1907
#  Last 10 training episodes: mean/median reward 11360.0/11450.0, min/max reward 8400.0/13700.0
#
# Updates 9682, num timesteps 9915392, FPS 1907
#  Last 10 training episodes: mean/median reward 11360.0/11450.0, min/max reward 8400.0/13700.0
#
# Updates 9683, num timesteps 9916416, FPS 1907
#  Last 10 training episodes: mean/median reward 11190.0/11450.0, min/max reward 8400.0/13700.0
#
# Updates 9684, num timesteps 9917440, FPS 1907
#  Last 10 training episodes: mean/median reward 11030.0/11100.0, min/max reward 8900.0/13700.0
#
# Updates 9685, num timesteps 9918464, FPS 1907
#  Last 10 training episodes: mean/median reward 10910.0/10750.0, min/max reward 8900.0/13700.0
#
# Updates 9686, num timesteps 9919488, FPS 1907
#  Last 10 training episodes: mean/median reward 10910.0/10750.0, min/max reward 8900.0/13700.0
#
# Updates 9687, num timesteps 9920512, FPS 1907
#  Last 10 training episodes: mean/median reward 10260.0/9950.0, min/max reward 6400.0/13700.0
#
# Updates 9688, num timesteps 9921536, FPS 1907
#  Last 10 training episodes: mean/median reward 9850.0/9500.0, min/max reward 6400.0/12900.0
#
# Updates 9689, num timesteps 9922560, FPS 1907
#  Last 10 training episodes: mean/median reward 9850.0/9500.0, min/max reward 6400.0/12900.0
#
# Updates 9690, num timesteps 9923584, FPS 1907
#  Last 10 training episodes: mean/median reward 9850.0/9500.0, min/max reward 6400.0/12900.0
#
# Updates 9691, num timesteps 9924608, FPS 1907
#  Last 10 training episodes: mean/median reward 10090.0/9950.0, min/max reward 6400.0/12900.0
#
# Updates 9692, num timesteps 9925632, FPS 1907
#  Last 10 training episodes: mean/median reward 10090.0/9950.0, min/max reward 6400.0/12900.0
#
# Updates 9693, num timesteps 9926656, FPS 1907
#  Last 10 training episodes: mean/median reward 10050.0/9950.0, min/max reward 6400.0/12900.0
#
# Updates 9694, num timesteps 9927680, FPS 1907
#  Last 10 training episodes: mean/median reward 10050.0/9950.0, min/max reward 6400.0/12900.0
#
# Updates 9695, num timesteps 9928704, FPS 1907
#  Last 10 training episodes: mean/median reward 10050.0/9950.0, min/max reward 6400.0/12900.0
#
# Updates 9696, num timesteps 9929728, FPS 1907
#  Last 10 training episodes: mean/median reward 10050.0/9950.0, min/max reward 6400.0/12900.0
#
# Updates 9697, num timesteps 9930752, FPS 1907
#  Last 10 training episodes: mean/median reward 9950.0/9450.0, min/max reward 6400.0/12900.0
#
# Updates 9698, num timesteps 9931776, FPS 1907
#  Last 10 training episodes: mean/median reward 9870.0/9450.0, min/max reward 6400.0/12900.0
#
# Updates 9699, num timesteps 9932800, FPS 1907
#  Last 10 training episodes: mean/median reward 9870.0/9450.0, min/max reward 6400.0/12900.0
#
# Updates 9700, num timesteps 9933824, FPS 1907
#  Last 10 training episodes: mean/median reward 9870.0/9450.0, min/max reward 6400.0/12900.0
#
# Updates 9701, num timesteps 9934848, FPS 1907
#  Last 10 training episodes: mean/median reward 9660.0/9200.0, min/max reward 6400.0/12900.0
#
# Updates 9702, num timesteps 9935872, FPS 1907
#  Last 10 training episodes: mean/median reward 9660.0/9200.0, min/max reward 6400.0/12900.0
#
# Updates 9703, num timesteps 9936896, FPS 1907
#  Last 10 training episodes: mean/median reward 9660.0/9200.0, min/max reward 6400.0/12900.0
#
# Updates 9704, num timesteps 9937920, FPS 1907
#  Last 10 training episodes: mean/median reward 9660.0/9200.0, min/max reward 6400.0/12900.0
#
# Updates 9705, num timesteps 9938944, FPS 1907
#  Last 10 training episodes: mean/median reward 9660.0/9200.0, min/max reward 6400.0/12900.0
#
# Updates 9706, num timesteps 9939968, FPS 1907
#  Last 10 training episodes: mean/median reward 9490.0/9200.0, min/max reward 6400.0/12900.0
#
# Updates 9707, num timesteps 9940992, FPS 1907
#  Last 10 training episodes: mean/median reward 9490.0/9200.0, min/max reward 6400.0/12900.0
#
# Updates 9708, num timesteps 9942016, FPS 1907
#  Last 10 training episodes: mean/median reward 9490.0/9200.0, min/max reward 6400.0/12900.0
#
# Updates 9709, num timesteps 9943040, FPS 1907
#  Last 10 training episodes: mean/median reward 9790.0/9200.0, min/max reward 6400.0/12900.0
#
# Updates 9710, num timesteps 9944064, FPS 1907
#  Last 10 training episodes: mean/median reward 9790.0/9200.0, min/max reward 6400.0/12900.0
#
# Updates 9711, num timesteps 9945088, FPS 1907
#  Last 10 training episodes: mean/median reward 10050.0/9200.0, min/max reward 7300.0/12900.0
#
# Updates 9712, num timesteps 9946112, FPS 1908
#  Last 10 training episodes: mean/median reward 10050.0/9200.0, min/max reward 7300.0/12900.0
#
# Updates 9713, num timesteps 9947136, FPS 1907
#  Last 10 training episodes: mean/median reward 9640.0/9200.0, min/max reward 7200.0/12700.0
#
# Updates 9714, num timesteps 9948160, FPS 1907
#  Last 10 training episodes: mean/median reward 9890.0/9200.0, min/max reward 7200.0/14200.0
#
# Updates 9715, num timesteps 9949184, FPS 1908
#  Last 10 training episodes: mean/median reward 9890.0/9200.0, min/max reward 7200.0/14200.0
#
# Updates 9716, num timesteps 9950208, FPS 1908
#  Last 10 training episodes: mean/median reward 9990.0/9200.0, min/max reward 7200.0/14200.0
#
# Updates 9717, num timesteps 9951232, FPS 1907
#  Last 10 training episodes: mean/median reward 10480.0/9750.0, min/max reward 7200.0/14200.0
#
# Updates 9718, num timesteps 9952256, FPS 1907
#  Last 10 training episodes: mean/median reward 10690.0/10250.0, min/max reward 7200.0/14200.0
#
# Updates 9719, num timesteps 9953280, FPS 1907
#  Last 10 training episodes: mean/median reward 10690.0/10250.0, min/max reward 7200.0/14200.0
#
# Updates 9720, num timesteps 9954304, FPS 1908
#  Last 10 training episodes: mean/median reward 11100.0/11500.0, min/max reward 7200.0/14200.0
#
# Updates 9721, num timesteps 9955328, FPS 1908
#  Last 10 training episodes: mean/median reward 11100.0/11500.0, min/max reward 7200.0/14200.0
#
# Updates 9722, num timesteps 9956352, FPS 1908
#  Last 10 training episodes: mean/median reward 11720.0/12700.0, min/max reward 7200.0/14200.0
#
# Updates 9723, num timesteps 9957376, FPS 1908
#  Last 10 training episodes: mean/median reward 11720.0/12700.0, min/max reward 7200.0/14200.0
#
# Updates 9724, num timesteps 9958400, FPS 1908
#  Last 10 training episodes: mean/median reward 11790.0/13000.0, min/max reward 7200.0/14200.0
# Updates 9725, num timesteps 9959424, FPS 1908
#  Last 10 training episodes: mean/median reward 11790.0/13000.0, min/max reward 7200.0/14200.0
#
# Updates 9726, num timesteps 9960448, FPS 1908
#  Last 10 training episodes: mean/median reward 11790.0/13000.0, min/max reward 7200.0/14200.0
#
# Updates 9727, num timesteps 9961472, FPS 1908
#  Last 10 training episodes: mean/median reward 12920.0/13350.0, min/max reward 10200.0/14400.0
#
# Updates 9728, num timesteps 9962496, FPS 1908
#  Last 10 training episodes: mean/median reward 12920.0/13350.0, min/max reward 10200.0/14400.0
#
# Updates 9729, num timesteps 9963520, FPS 1908
#  Last 10 training episodes: mean/median reward 12920.0/13350.0, min/max reward 10200.0/14400.0
#
# Updates 9730, num timesteps 9964544, FPS 1908
#  Last 10 training episodes: mean/median reward 12920.0/13350.0, min/max reward 10200.0/14400.0
#
# Updates 9731, num timesteps 9965568, FPS 1908
#  Last 10 training episodes: mean/median reward 12920.0/13350.0, min/max reward 10200.0/14400.0
#
# Updates 9732, num timesteps 9966592, FPS 1908
#  Last 10 training episodes: mean/median reward 11900.0/13200.0, min/max reward 2900.0/14400.0
#
# Updates 9733, num timesteps 9967616, FPS 1907
#  Last 10 training episodes: mean/median reward 11360.0/13200.0, min/max reward 2900.0/14400.0
#
# Updates 9734, num timesteps 9968640, FPS 1907
#  Last 10 training episodes: mean/median reward 10450.0/12250.0, min/max reward 2900.0/14400.0
#
# Updates 9735, num timesteps 9969664, FPS 1907
#  Last 10 training episodes: mean/median reward 10660.0/12700.0, min/max reward 2900.0/14400.0
#
# Updates 9736, num timesteps 9970688, FPS 1907
#  Last 10 training episodes: mean/median reward 8390.0/7250.0, min/max reward 2900.0/14400.0
#
# Updates 9737, num timesteps 9971712, FPS 1907
#  Last 10 training episodes: mean/median reward 8390.0/7250.0, min/max reward 2900.0/14400.0
#
# Updates 9738, num timesteps 9972736, FPS 1907
#  Last 10 training episodes: mean/median reward 8390.0/7250.0, min/max reward 2900.0/14400.0
#
# Updates 9739, num timesteps 9973760, FPS 1907
#  Last 10 training episodes: mean/median reward 8390.0/7250.0, min/max reward 2900.0/14400.0
#
# Updates 9740, num timesteps 9974784, FPS 1907
#  Last 10 training episodes: mean/median reward 8390.0/7250.0, min/max reward 2900.0/14400.0
#
# Updates 9741, num timesteps 9975808, FPS 1907
#  Last 10 training episodes: mean/median reward 7340.0/7000.0, min/max reward 2900.0/13100.0
#
# Updates 9742, num timesteps 9976832, FPS 1907
#  Last 10 training episodes: mean/median reward 7340.0/7000.0, min/max reward 2900.0/13100.0
#
# Updates 9743, num timesteps 9977856, FPS 1907
#  Last 10 training episodes: mean/median reward 6290.0/5900.0, min/max reward 2600.0/12300.0
#
# Updates 9744, num timesteps 9978880, FPS 1907
#  Last 10 training episodes: mean/median reward 6630.0/6550.0, min/max reward 2600.0/12300.0
#
# Updates 9745, num timesteps 9979904, FPS 1908
#  Last 10 training episodes: mean/median reward 6630.0/6550.0, min/max reward 2600.0/12300.0
#
# Updates 9746, num timesteps 9980928, FPS 1908
#  Last 10 training episodes: mean/median reward 5880.0/5650.0, min/max reward 2600.0/12300.0
#
# Updates 9747, num timesteps 9981952, FPS 1908
#  Last 10 training episodes: mean/median reward 5880.0/5650.0, min/max reward 2600.0/12300.0
#
# Updates 9748, num timesteps 9982976, FPS 1908
#  Last 10 training episodes: mean/median reward 5750.0/5100.0, min/max reward 2600.0/12300.0
#
# Updates 9749, num timesteps 9984000, FPS 1908
#  Last 10 training episodes: mean/median reward 4870.0/3800.0, min/max reward 2600.0/7600.0
#
# Updates 9750, num timesteps 9985024, FPS 1908
#  Last 10 training episodes: mean/median reward 4870.0/3800.0, min/max reward 2600.0/7600.0
#
# Updates 9751, num timesteps 9986048, FPS 1908
#  Last 10 training episodes: mean/median reward 4870.0/3800.0, min/max reward 2600.0/7600.0
#
# Updates 9752, num timesteps 9987072, FPS 1908
#  Last 10 training episodes: mean/median reward 4630.0/3900.0, min/max reward 2600.0/7600.0
#
# Updates 9753, num timesteps 9988096, FPS 1908
#  Last 10 training episodes: mean/median reward 4350.0/3900.0, min/max reward 2600.0/7600.0
#
# Updates 9754, num timesteps 9989120, FPS 1908
#  Last 10 training episodes: mean/median reward 4350.0/3900.0, min/max reward 2600.0/7600.0
#
# Updates 9755, num timesteps 9990144, FPS 1908
#  Last 10 training episodes: mean/median reward 4350.0/3900.0, min/max reward 2600.0/7600.0
#
# Updates 9756, num timesteps 9991168, FPS 1908
#  Last 10 training episodes: mean/median reward 4350.0/3900.0, min/max reward 2600.0/7600.0
#
# Updates 9757, num timesteps 9992192, FPS 1908
#  Last 10 training episodes: mean/median reward 4350.0/3850.0, min/max reward 2700.0/7600.0
#
# Updates 9758, num timesteps 9993216, FPS 1908
#  Last 10 training episodes: mean/median reward 4350.0/3850.0, min/max reward 2700.0/7600.0
#
# Updates 9759, num timesteps 9994240, FPS 1908
#  Last 10 training episodes: mean/median reward 3960.0/3850.0, min/max reward 2700.0/5500.0
#
# Updates 9760, num timesteps 9995264, FPS 1908
#  Last 10 training episodes: mean/median reward 3960.0/3850.0, min/max reward 2700.0/5500.0
#
# Updates 9761, num timesteps 9996288, FPS 1908
#  Last 10 training episodes: mean/median reward 4100.0/3950.0, min/max reward 2700.0/5500.0
#
# Updates 9762, num timesteps 9997312, FPS 1908
#  Last 10 training episodes: mean/median reward 4100.0/3950.0, min/max reward 2700.0/5500.0
#
# Updates 9763, num timesteps 9998336, FPS 1908
#  Last 10 training episodes: mean/median reward 4100.0/3950.0, min/max reward 2700.0/5500.0
#
# Updates 9764, num timesteps 9999360, FPS 1908
#  Last 10 training episodes: mean/median reward 4550.0/4200.0, min/max reward 2700.0/8200.0

# %%
# !git clone https://github.com/ikostrikov/pytorch-a2c-ppo-acktr
# Out:
# fatal: destination path 'pytorch-a2c-ppo-acktr' already exists and is not an empty directory.

# %%
import copy
# ?copy_()
# Out:
# Object `copy_` not found.

# %%
# !cd pytorch-a2c-ppo-acktr && ls
# Out:
# LICENSE      algo	       enjoy.py  main.py	   storage.py
# README.md    arguments.py      envs.py	 model.py	   utils.py
# __pycache__  distributions.py  imgs	 requirements.txt  visualize.py

# %%
# !ls
# Out:
# Desktop
# Dockerfile
# Dockerfile-Digits-TRT
# Dockerfile-PyTorch
# Dockerfile-TF
# Dockerfile-mxNet-gym-jupyter-python3
# Dockerfile-ubuntu-gym-explicit-dependencies
# Dockerfile-viz-experiments-converting-to-internal-ssh
# Dockerfile_torch_TF_gym_baselines_jupyter
# Dockerfile_ubu_gym
# Dropbox
# RL_sc2
# RL_workflow.ipynb
# StarCraftII
# Untitled.ipynb
# baselines
# cRL
# cross-entropy-RL.ipynb
# dropbox_2015.10.28_amd64.deb
# gx-drl-starcraft2
# gym
# kung_fu_example.ipynb
# kung_fu_example_plot.ipynb
# launch_notebook.sh
# model_checkpoints
# nnViz
# pytorch-a2c-ppo-acktr
# run-RL.sh
# run-pytorch-rl.sh
# run-ssh-container.sh
# runp3.sh
# sudo
# teach_DL
# unused_docker_launch

# %%
# !cd /workspace/pytorch-a2c-ppo-acktr/logs/kungFuMaster16WorkersPPO_10E6Frames/ && ls
# Out:
# 0.monitor.csv	12.monitor.csv	2.monitor.csv  6.monitor.csv
# 1.monitor.csv	13.monitor.csv	3.monitor.csv  7.monitor.csv
# 10.monitor.csv	14.monitor.csv	4.monitor.csv  8.monitor.csv
# 11.monitor.csv	15.monitor.csv	5.monitor.csv  9.monitor.csv

# %%
filenameStr = '/workspace/pytorch-a2c-ppo-acktr/logs/kungFuMaster16WorkersPPO_10E6Frames/0.monitor.csv'

# %%
import csv
with open(filenameStr) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        print('line_count: ' + str(line_count) + ' ' + str(row))
        line_count += 1
        if line_count > 50: 
            break
# Out:
# line_count: 0 ['# {"t_start": 1538689431.0785897', ' "env_id": "KungFuMasterNoFrameskip-v0"} ']
# line_count: 1 ['r', 'l', 't']
# line_count: 2 ['1400.0', '1274', '15.14824']
# line_count: 3 ['600.0', '914', '23.311084']
# line_count: 4 ['2900.0', '1410', '34.948618']
# line_count: 5 ['3000.0', '1841', '51.5895']
# line_count: 6 ['5300.0', '1538', '64.610755']
# line_count: 7 ['3200.0', '1447', '77.308612']
# line_count: 8 ['5700.0', '1844', '92.103877']
# line_count: 9 ['2500.0', '1029', '100.475183']
# line_count: 10 ['3600.0', '1416', '111.983961']
# line_count: 11 ['3600.0', '1406', '123.241364']
# line_count: 12 ['5800.0', '1629', '136.536898']
# line_count: 13 ['5200.0', '1643', '150.414382']
# line_count: 14 ['7900.0', '2054', '167.390019']
# line_count: 15 ['4000.0', '1750', '182.14237']
# line_count: 16 ['4200.0', '1486', '194.366994']
# line_count: 17 ['3900.0', '1787', '209.135054']
# line_count: 18 ['8000.0', '2035', '225.864668']
# line_count: 19 ['3800.0', '1682', '240.194664']
# line_count: 20 ['2000.0', '1370', '251.380193']
# line_count: 21 ['5400.0', '1427', '263.322704']
# line_count: 22 ['3100.0', '1520', '275.710244']
# line_count: 23 ['2200.0', '1398', '287.340107']
# line_count: 24 ['5000.0', '1840', '302.478907']
# line_count: 25 ['3800.0', '1631', '315.819643']
# line_count: 26 ['8600.0', '2169', '333.46057']
# line_count: 27 ['5800.0', '1746', '347.663905']
# line_count: 28 ['5200.0', '1744', '362.184815']
# line_count: 29 ['7200.0', '2104', '378.990188']
# line_count: 30 ['2800.0', '1365', '390.621506']
# line_count: 31 ['6800.0', '1580', '403.48102']
# line_count: 32 ['3900.0', '1676', '417.519429']
# line_count: 33 ['5800.0', '1694', '431.639723']
# line_count: 34 ['8400.0', '2114', '449.608474']
# line_count: 35 ['5500.0', '1908', '466.458337']
# line_count: 36 ['3600.0', '1514', '479.683641']
# line_count: 37 ['6500.0', '1956', '495.490517']
# line_count: 38 ['6700.0', '2013', '512.153821']
# line_count: 39 ['5300.0', '1693', '525.856322']
# line_count: 40 ['8200.0', '2283', '543.971654']
# line_count: 41 ['5400.0', '1750', '558.306005']
# line_count: 42 ['4700.0', '1681', '572.788179']
# line_count: 43 ['8800.0', '2075', '591.441942']
# line_count: 44 ['4300.0', '1626', '605.640067']
# line_count: 45 ['3900.0', '1417', '618.776562']
# line_count: 46 ['5100.0', '1633', '633.199362']
# line_count: 47 ['6800.0', '1957', '650.75155']
# line_count: 48 ['5500.0', '1841', '665.518385']
# line_count: 49 ['5500.0', '1875', '680.846571']
# line_count: 50 ['8100.0', '2264', '699.336834']

# %% [markdown]
# # End of file

# %%
filenameStr = '/workspace/pytorch-a2c-ppo-acktr/logs/kungFuMaster16WorkersPPO_10E6Frames/0.monitor.csv'

# %%
import csv
line_count = 0
with open(filenameStr) as csv_file:
    for row in reversed(list(csv.reader(csv_file))):
        print (str(row))
        line_count += 1
        if line_count > 50: 
            break
# Out:
# ['4000.0', '1338', '5236.940077']
# ['11400.0', '2238', '5225.778916']
# ['8100.0', '1711', '5207.680066']
# ['12900.0', '2057', '5193.881849']
# ['9800.0', '1984', '5177.375161']
# ['15900.0', '2514', '5161.372077']
# ['14800.0', '2365', '5140.334826']
# ['15300.0', '2292', '5119.762178']
# ['19500.0', '2749', '5101.177001']
# ['18000.0', '2493', '5079.196374']
# ['14800.0', '2022', '5058.957649']
# ['13400.0', '2005', '5042.7717']
# ['12700.0', '2061', '5026.46484']
# ['10900.0', '2169', '5009.549408']
# ['14600.0', '2065', '4991.695343']
# ['16300.0', '2415', '4974.733234']
# ['20200.0', '2458', '4952.974336']
# ['16900.0', '2338', '4930.677069']
# ['14800.0', '2343', '4909.711287']
# ['16000.0', '2108', '4891.183054']
# ['16400.0', '2415', '4874.305523']
# ['19400.0', '2368', '4854.381856']
# ['14900.0', '2124', '4835.476744']
# ['15900.0', '2286', '4818.356371']
# ['16900.0', '2386', '4800.078104']
# ['16600.0', '2458', '4779.018858']
# ['15500.0', '2220', '4758.550923']
# ['12600.0', '1818', '4739.939733']
# ['15700.0', '2149', '4725.321468']
# ['21300.0', '2794', '4707.266839']
# ['11900.0', '1810', '4683.593824']
# ['16800.0', '2298', '4668.608367']
# ['7800.0', '1513', '4650.088764']
# ['11300.0', '1850', '4637.358016']
# ['7200.0', '1369', '4621.447456']
# ['9900.0', '1623', '4610.259747']
# ['11000.0', '2020', '4596.988451']
# ['14100.0', '2127', '4579.657223']
# ['11900.0', '1918', '4562.518274']
# ['14200.0', '2147', '4547.09111']
# ['10700.0', '1938', '4528.496157']
# ['17500.0', '2816', '4511.736721']
# ['9500.0', '1496', '4486.463723']
# ['23000.0', '3136', '4473.737432']
# ['12600.0', '2167', '4446.738845']
# ['13300.0', '2197', '4427.246047']
# ['8800.0', '1888', '4408.111977']
# ['11100.0', '1714', '4391.740292']
# ['10000.0', '2057', '4376.357074']
# ['16800.0', '2343', '4357.603079']
# ['8800.0', '1597', '4338.752384']

# %% [markdown]
# # Capture Reward and Plot

# %%
import csv
data = []
line_count = 0
with open(filenameStr) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        #print('line_count: ' + str(line_count) + ' ' + str(row))
        line_count += 1
        
        if line_count > 2:
            #print('   reward: ' + str(row[0]))
            #print(type(float(row[0])))        
            data += [ float( row[0]) ]
        #if line_count > 1000:
        #    print(data)
        #    break

# %%
plt.figure()
plt.plot(data)

# %%
len(data)
# Out:
# 304

# %%
plt.show()

# %%
#!pip install pandas

# %%
dataDF = pd.DataFrame(data)

# %%
plt.plot(dataDF.rolling(window=25).mean())

# %%
16*300
# Out:
# 120000

# %% [markdown]
# # Behavior Vids [ frame capture from agent chosen actions at var points in learning curve]

# %% [markdown]
# <code>user selects P=3 points --
#        build code to run inference on checkpointed model
#         @ closest available make P video loops; NF=100 frames per video loop</code>

# %% [markdown]
# TODO: determine frame to checkpoint mapping
