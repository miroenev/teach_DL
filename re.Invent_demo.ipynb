# %% [markdown]
# # Training a commute prediction network, and visualizing learning!
# <ul> latest version available from: https://github.com/miroenev/teach_DL , prerequisites:
# * Matplotlib, Numpy, MxNet, and <a href="https://github.com/K3D-tools/K3D-jupyter">K3D</a> for realtime training 3D surface visualization
#
# A video walkthrough of this notebook is <a href='https://youtu.be/HgbGJn9yz30'> available on YouTube</a>.

# %%
import numpy as np
import matplotlib.pylab as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# %matplotlib notebook

# %%
import mxnet as mx

# %% [markdown]
# # Define the problem
#
# Lets try to predict commute duration from two observable independent variables: the time of day and the weather conditions.
#
# <img src='figures/commute.png' width='400'/>
# <img src='figures/target_distribution.PNG' width='1000'/>
# In this toy example we'll first take on the role of the 'traffic gods' and decree that commute duration is defined through a linear mixture of the two independent variables. Later we'll sample from the distribution defined by these variables and generate a training dataset. This sampling procedure will be analogous to keeping a journal of all of our commutes for some [ long ] period of time, where each log entry consists of a set of
# * <b>X</b>: [ time-of-departure, weather-condition ], and the associated
# * <b>Y</b>: [ commute-duration ].
#
# <img src='figures/x_y_mapping.PNG' width='900'/>
#
# Given such a journal [dataset], we'll split it into training (75%) and testing (25%) subsets which we'll use to train and evaulate our model respectively. Specifically, we'll build a neural network model whose weights are initially randomly initialized, but are trained/updated as we stream the training data through (via the backpropagation learning algorithm). Each update will get us closer to having a model that has learned the relationship between X and Y or ([ time-of-departure, weather-condition ] to [ commute-duration] ).
#
# <img src='figures/process.PNG' width='800'/>
#
# During the training process we'll try to visualize the network's behavior by asking it to predict all the entries in our logbook using its current parameters/weights. As the training process unfolds, you should be able to see how the network adapts itself to the target surface/function that we determined for the commute duration.
#
# <img src='figures/training_progress.PNG' width='700'/>

# %% [markdown]
# # Determine underlying relationship
# We'll start by esablishing (as traffic gods) the relationships between:
# * 1) the time a commute starts (time-of-departure variable) and commute-duration
# * 2) the weather when a commute is started (weather-condtion variable) and commute-duration
#
# Note that as data scientists we never get to see this function, but we try to learn it from data.

# %%
# define data coordinates
xRange = [0,10]; 
yRange = [0,10]; numSteps = 100

x, y = np.meshgrid( np.linspace(xRange[0], xRange[1], numSteps),
                    np.linspace(yRange[0], yRange[1], numSteps), indexing='ij' )

def normalize_domain (x):
    x = x + np.abs(np.min(x))
    x = x / (np.max(x) + .001)
    return x
    
# define 1D relationships to target
xComponent = np.sin( x ) * 4
yComponent = np.exp( y / 4 )

# define 2D joint distribution
z = xComponent + yComponent
z = normalize_domain(z)


# plot independent variables
plt.figure( figsize = ( 7, 7) )
plt.subplots_adjust( left = 0.1, right = 0.9, top = 0.9, bottom = 0.1, wspace = 0.2 )
plt.subplot(2,1,1); plt.plot(normalize_domain(xComponent[:,0])); plt.xlabel('time-of-day'), plt.ylabel('commute duration')
plt.xticks([]), plt.yticks([])
plt.subplot(2,1,2); plt.plot(normalize_domain(yComponent[0,:])); plt.xlabel('weather [ severity ]'), plt.ylabel('commute duration')
plt.xticks([]), plt.yticks([])

# plot target [dependent] variable
plt.figure( figsize = (9, 9) )
plt.subplots_adjust( left = 0.1, right = 0.9, top = 0.9, bottom = 0.1 )
ax = plt.subplot(1,1,1, projection='3d');
ax.plot_surface ( x[0::1], y[0::1], z[0::1], color = 'blue', alpha = 1, antialiased = False )
ax.set_xlabel('time of day')
ax.set_ylabel('severity of weather')
ax.set_zlabel('commute length')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="699.7333333333333">
# <img src="data:image/png;base64,..." width="899.7333333333333">

# %% [markdown]
# # Generate  dataset
# Lets generate a dataset by randomly sampling from the target distribution [ with some noise ].

# %%
NSamples = 5000
noiseScaling = 1/8.

shuffledDataIndsX = np.random.randint(x.shape[0], size=(NSamples,1))
shuffledDataIndsY = np.random.randint(y.shape[0], size=(NSamples,1))

trainData = np.zeros( ( NSamples, 2 ) )
targetValues = np.zeros( (NSamples, 1 ))
noiseAmount = noiseScaling * ( np.random.rand(NSamples) - .5 )

for iSample in range (NSamples):
    trainData[iSample, 0] = x[ shuffledDataIndsX[iSample], 0 ]
    trainData[iSample, 1] = y[ 0, shuffledDataIndsY[iSample] ]    
    targetValues[iSample] = z[ shuffledDataIndsX[iSample], shuffledDataIndsY[iSample] ] + noiseAmount[iSample]

# %% [markdown]
# # Plot dataset samples (red dots) overlayed onto target distribution (blue)

# %%
from k3d import K3D

plot = K3D()
zScaling = 6

offset = np.hstack( ( np.ones((trainData.shape[0], 1)) * -5, 
                      np.ones((trainData.shape[0], 1)) + 4, 
                      np.zeros((trainData.shape[0], 1)) ) ) * np.abs(xRange[1]-xRange[0])

plot += K3D.points ( np.hstack( ( trainData, targetValues*zScaling) ) + offset, color=0xFF0000, point_size = .2, shader = 'flat' )
plot += K3D.surface ( z*zScaling, color=0x0055FF, xmin=np.min(trainData[:,0]+offset[::,0]), xmax=np.max(trainData[:,0]+offset[::,0]), ymin=np.min(trainData[:,1]+offset[::,1]), ymax=np.max(trainData[:,1]+offset[::,1]))

plot.display()
# Out:
# K3D(parameters={'backgroundColor': 16777215, 'height': 512, 'antialias': True})

# %% [markdown]
# # Create Data Iterators

# %%
data = trainData
label = targetValues[:,0]

trainIterator = mx.io.NDArrayIter( data = data, label = label, 
                                   data_name = 'data', 
                                   label_name = 'linearOutput_label', batch_size = 512)

predictIterator = mx.io.NDArrayIter( data = data, label = label, 
                                     data_name = 'data', 
                                     label_name = 'linearOutput_label', batch_size = NSamples)

# %% [markdown]
# # Define model structure

# %%
import mxnet as mx

inputData = mx.sym.Variable('data')
targetLabelVar = mx.sym.Variable('linearOutput_label') 

layer1 = mx.sym.FullyConnected( data = inputData, name = 'fc1', num_hidden = 5)
layer1Activation = mx.sym.Activation( data = layer1, name = 'sig1', act_type = "sigmoid")

layer2 = mx.sym.FullyConnected( data = layer1Activation, name='fc2', num_hidden = 27)
layer2Activation = mx.sym.Activation( data = layer2, name='sig2', act_type = "sigmoid")

layer3 = mx.sym.FullyConnected( data = layer2Activation, name='fc3', num_hidden = 20)
layer3Activation = mx.sym.Activation( data = layer3, name='sig3', act_type = "sigmoid")

layer4 = mx.sym.FullyConnected( data = layer3Activation, name = 'fc4', num_hidden = 40)
layer4Activation = mx.sym.Activation( data = layer4, name = 'sig4', act_type = "sigmoid")

output = mx.sym.FullyConnected( data = layer4Activation, name='output', num_hidden=1)

loss = mx.sym.LinearRegressionOutput( data = output, label = targetLabelVar , name = 'linearOutput_label')

# %%
mod = mx.mod.Module(symbol = loss,
                    context = mx.gpu(0),
                    data_names = ['data'],
                    label_names = ['linearOutput_label'])

# %%
# allocate memory given the input data and label shapes
mod.bind( data_shapes = trainIterator.provide_data, label_shapes = trainIterator.provide_label )

# %%
# initialize parameters by uniform random numbers
mod.init_params( initializer = mx.init.Xavier(), force_init = True)

# %%
# use adam optimizer
mod.init_optimizer( optimizer = 'adam' )

# %%
# use root mean squared error as the metric
metric = mx.metric.create( 'rmse' )

# %% [markdown]
# # Visualize network structure

# %%
mx.viz.plot_network( loss )

# %%
import importlib
import nnViz_mxnet
importlib.reload(nnViz_mxnet)
# Out:
# <module 'nnViz_mxnet' from '/home/ubuntu/mxnet_dev/nnViz_mxnet.py'>

# %%
nnViz_mxnet.visualize_model(mod)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Model structure [loosely] inspired by NVIDIA's new HQ ;]
# http://c.ymcdn.com/sites/aiascv.org/resource/resmgr/meeting_images/2017/March/Nv2.jpeg

# %% [markdown]
# # Train Model v1

# %%
import logging
logging.getLogger().setLevel(logging.DEBUG)
mod.fit(data_iter,
          optimizer = 'adam',`
          eval_metric = 'rmse',
          num_epoch = 50)

# %% [markdown]
# # Train Model v2

# %%
# time ...
for epoch in range(100):
    
    trainIterator.reset()
    metric.reset()
    
    for batch in trainIterator:
        
        mod.forward( batch, is_train = True )       # compute predictions
        mod.update_metric( metric, batch.label )    # accumulate prediction accuracy
        mod.backward()                              # compute gradients
        mod.update()                                # update parameters
    
    print('Epoch %d, Training %s' % (epoch, metric.get()))

# %% [markdown]
# # Train Model + Visualize

# %%
# initialize parameters by uniform random numbers
mod.init_params( initializer = mx.init.Xavier(), force_init = True)

# %%
NEpochs = 350
displayUpdateInterval = 10

currentNN = {}
plotCount = 0

xOffset = np.zeros( (trainData.shape[0], 1))
yOffset = np.zeros( (trainData.shape[0], 1))
zOffset = np.zeros( (trainData.shape[0], 1))

xModifier = 1 * np.abs(xRange[1]-xRange[0])*1.2; yModifier = 0; zModifier = 0; 
plotCount = 0

evalLoss = np.empty((NEpochs))
evalLoss[:] = np.NaN

predictIterator.reset()
nextIterData = predictIterator.next()
batchInputs = nextIterData.data[0].asnumpy()


# train 5 epochs, i.e. going over the data iter one pass
for iEpoch in range(NEpochs):
    
    trainIterator.reset()
    metric.reset()
    
    for batch in trainIterator:
        mod.forward( batch, is_train = True )     # compute predictions
        mod.update_metric( metric, batch.label )  # accumulate prediction accuracy
        mod.backward()                            # compute gradients
        mod.update()                              # update parameters
    
    evalLoss[iEpoch] = metric.get()[1]
    print('Epoch: %d, Training Loss: %s' % ( iEpoch, evalLoss[iEpoch] ))
    
    
    # plotting 
    if iEpoch % displayUpdateInterval == 0:
        
        mod.forward( nextIterData )
        
        currentNN[plotCount] = mod.get_outputs()[0].asnumpy()

        comboOffset = np.hstack( (xOffset + xModifier, yOffset + yModifier, zOffset + zModifier) )
        plot += K3D.points ( np.hstack( ( batchInputs, currentNN[plotCount] * zScaling) ) + comboOffset + offset, color=0xA9A9FF, point_size = .2, shader = 'flat' )        
        plot += K3D.text2d ( str( round( evalLoss[iEpoch], 4 )), comboOffset + offset + (0, 0, 3), color=0xff00ff, size=.5, reference_point='rb')
        
        
        plotCount += 1
        if plotCount % 8 == 0:
            xModifier = 1 * np.abs(xRange[1]-xRange[0])*1.2
            yModifier -= 1 * np.abs(yRange[1]-yRange[0])*1.2
        else:
            xModifier += 1 * np.abs(xRange[1]-xRange[0])*1.2
# Out:
# Epoch: 0, Training Loss: 0.595272776484
# Epoch: 1, Training Loss: 0.322101809084
# Epoch: 2, Training Loss: 0.254798108339
# Epoch: 3, Training Loss: 0.237330217659
# Epoch: 4, Training Loss: 0.223014694452
# Epoch: 5, Training Loss: 0.218440894783
# Epoch: 6, Training Loss: 0.21334271878
# Epoch: 7, Training Loss: 0.210285511613
# Epoch: 8, Training Loss: 0.205261021852
# Epoch: 9, Training Loss: 0.199772612751
# Epoch: 10, Training Loss: 0.191954557598
# Epoch: 11, Training Loss: 0.183831775188
# Epoch: 12, Training Loss: 0.176315756142
# Epoch: 13, Training Loss: 0.170471172035
# Epoch: 14, Training Loss: 0.165563389659
# Epoch: 15, Training Loss: 0.160851924121
# Epoch: 16, Training Loss: 0.156882430613
# Epoch: 17, Training Loss: 0.153896014392
# Epoch: 18, Training Loss: 0.15182402581
# Epoch: 19, Training Loss: 0.150441667438
# Epoch: 20, Training Loss: 0.14951492846
# Epoch: 21, Training Loss: 0.148877897859
# Epoch: 22, Training Loss: 0.148424161971
# Epoch: 23, Training Loss: 0.148089304566
# Epoch: 24, Training Loss: 0.147834943235
# Epoch: 25, Training Loss: 0.147638393939
# Epoch: 26, Training Loss: 0.147485250235
# Epoch: 27, Training Loss: 0.147365796566
# Epoch: 28, Training Loss: 0.147273163497
# Epoch: 29, Training Loss: 0.14720197469
# Epoch: 30, Training Loss: 0.147147649527
# Epoch: 31, Training Loss: 0.147106172144
# Epoch: 32, Training Loss: 0.147073960304
# Epoch: 33, Training Loss: 0.147047914565
# Epoch: 34, Training Loss: 0.147025343776
# Epoch: 35, Training Loss: 0.147003997862
# Epoch: 36, Training Loss: 0.146981953084
# Epoch: 37, Training Loss: 0.146957597136
# Epoch: 38, Training Loss: 0.146929553151
# Epoch: 39, Training Loss: 0.146896652877
# Epoch: 40, Training Loss: 0.146857894957
# Epoch: 41, Training Loss: 0.146812438965
# Epoch: 42, Training Loss: 0.146759556234
# Epoch: 43, Training Loss: 0.146698671579
# Epoch: 44, Training Loss: 0.146629345417
# Epoch: 45, Training Loss: 0.146551282704
# Epoch: 46, Training Loss: 0.14646435678
# Epoch: 47, Training Loss: 0.146368607879
# Epoch: 48, Training Loss: 0.14626429379
# Epoch: 49, Training Loss: 0.146151873469
# Epoch: 50, Training Loss: 0.146032042801
# Epoch: 51, Training Loss: 0.145905733109
# Epoch: 52, Training Loss: 0.145774117112
# Epoch: 53, Training Loss: 0.145638568699
# Epoch: 54, Training Loss: 0.145500651002
# Epoch: 55, Training Loss: 0.145362059772
# Epoch: 56, Training Loss: 0.145224522054
# Epoch: 57, Training Loss: 0.145089776814
# Epoch: 58, Training Loss: 0.144959415495
# Epoch: 59, Training Loss: 0.144834817946
# Epoch: 60, Training Loss: 0.144717055559
# Epoch: 61, Training Loss: 0.144606867433
# Epoch: 62, Training Loss: 0.144504606724
# Epoch: 63, Training Loss: 0.144410295784
# Epoch: 64, Training Loss: 0.144323679805
# Epoch: 65, Training Loss: 0.144244293869
# Epoch: 66, Training Loss: 0.144171603024
# Epoch: 67, Training Loss: 0.144105014205
# Epoch: 68, Training Loss: 0.144043970108
# Epoch: 69, Training Loss: 0.143987959623
# Epoch: 70, Training Loss: 0.143936507404
# Epoch: 71, Training Loss: 0.143889182806
# Epoch: 72, Training Loss: 0.143845593929
# Epoch: 73, Training Loss: 0.143805380166
# Epoch: 74, Training Loss: 0.143768231571
# Epoch: 75, Training Loss: 0.143733854592
# Epoch: 76, Training Loss: 0.14370200485
# Epoch: 77, Training Loss: 0.143672454357
# Epoch: 78, Training Loss: 0.143645003438
# Epoch: 79, Training Loss: 0.143619474769
# Epoch: 80, Training Loss: 0.143595699966
# Epoch: 81, Training Loss: 0.143573544919
# Epoch: 82, Training Loss: 0.143552874029
# Epoch: 83, Training Loss: 0.143533581495
# Epoch: 84, Training Loss: 0.14351555109
# Epoch: 85, Training Loss: 0.143498691916
# Epoch: 86, Training Loss: 0.143482923508
# Epoch: 87, Training Loss: 0.143468166888
# Epoch: 88, Training Loss: 0.143454349041
# Epoch: 89, Training Loss: 0.143441408873
# Epoch: 90, Training Loss: 0.143429288268
# Epoch: 91, Training Loss: 0.143417924643
# Epoch: 92, Training Loss: 0.143407283723
# Epoch: 93, Training Loss: 0.143397310376
# Epoch: 94, Training Loss: 0.143387964368
# Epoch: 95, Training Loss: 0.143379205465
# Epoch: 96, Training Loss: 0.143371006846
# Epoch: 97, Training Loss: 0.143363326788
# Epoch: 98, Training Loss: 0.143356142938
# Epoch: 99, Training Loss: 0.143349421024
# Epoch: 100, Training Loss: 0.143343137205
# Epoch: 101, Training Loss: 0.143337272108
# Epoch: 102, Training Loss: 0.143331795931
# Epoch: 103, Training Loss: 0.143326693773
# Epoch: 104, Training Loss: 0.143321943283
# Epoch: 105, Training Loss: 0.143317526579
# Epoch: 106, Training Loss: 0.143313427269
# Epoch: 107, Training Loss: 0.143309624493
# Epoch: 108, Training Loss: 0.143306110799
# Epoch: 109, Training Loss: 0.143302872777
# Epoch: 110, Training Loss: 0.143299897015
# Epoch: 111, Training Loss: 0.143297162652
# Epoch: 112, Training Loss: 0.143294669688
# Epoch: 113, Training Loss: 0.143292406201
# Epoch: 114, Training Loss: 0.143290357292
# Epoch: 115, Training Loss: 0.143288518488
# Epoch: 116, Training Loss: 0.14328687638
# Epoch: 117, Training Loss: 0.143285430968
# Epoch: 118, Training Loss: 0.143284168839
# Epoch: 119, Training Loss: 0.143283087015
# Epoch: 120, Training Loss: 0.143282175064
# Epoch: 121, Training Loss: 0.143281430006
# Epoch: 122, Training Loss: 0.143280845881
# Epoch: 123, Training Loss: 0.143280419707
# Epoch: 124, Training Loss: 0.143280147016
# Epoch: 125, Training Loss: 0.143280020356
# Epoch: 126, Training Loss: 0.143280038238
# Epoch: 127, Training Loss: 0.14328019619
# Epoch: 128, Training Loss: 0.143280491233
# Epoch: 129, Training Loss: 0.143280924857
# Epoch: 130, Training Loss: 0.143281492591
# Epoch: 131, Training Loss: 0.143282189965
# Epoch: 132, Training Loss: 0.143283013999
# Epoch: 133, Training Loss: 0.143283970654
# Epoch: 134, Training Loss: 0.143285050988
# Epoch: 135, Training Loss: 0.143286257982
# Epoch: 136, Training Loss: 0.143287587166
# Epoch: 137, Training Loss: 0.14328904897
# Epoch: 138, Training Loss: 0.143290632963
# Epoch: 139, Training Loss: 0.143292333186
# Epoch: 140, Training Loss: 0.143294170499
# Epoch: 141, Training Loss: 0.143296121061
# Epoch: 142, Training Loss: 0.143298210204
# Epoch: 143, Training Loss: 0.143300417066
# Epoch: 144, Training Loss: 0.143302755058
# Epoch: 145, Training Loss: 0.1433052212
# Epoch: 146, Training Loss: 0.143307816982
# Epoch: 147, Training Loss: 0.143310546875
# Epoch: 148, Training Loss: 0.143313403428
# Epoch: 149, Training Loss: 0.143316395581
# Epoch: 150, Training Loss: 0.143319526315
# Epoch: 151, Training Loss: 0.14332279712
# Epoch: 152, Training Loss: 0.143326200545
# Epoch: 153, Training Loss: 0.143329747021
# Epoch: 154, Training Loss: 0.143333435059
# Epoch: 155, Training Loss: 0.143337269127
# Epoch: 156, Training Loss: 0.143341249228
# Epoch: 157, Training Loss: 0.143345372379
# Epoch: 158, Training Loss: 0.143349644542
# Epoch: 159, Training Loss: 0.143354067206
# Epoch: 160, Training Loss: 0.143358635902
# Epoch: 161, Training Loss: 0.14336335063
# Epoch: 162, Training Loss: 0.143368218839
# Epoch: 163, Training Loss: 0.14337322861
# Epoch: 164, Training Loss: 0.143378384411
# Epoch: 165, Training Loss: 0.143383692205
# Epoch: 166, Training Loss: 0.143389125168
# Epoch: 167, Training Loss: 0.143394693732
# Epoch: 168, Training Loss: 0.143400387466
# Epoch: 169, Training Loss: 0.143406204879
# Epoch: 170, Training Loss: 0.14341212213
# Epoch: 171, Training Loss: 0.143418121338
# Epoch: 172, Training Loss: 0.143424205482
# Epoch: 173, Training Loss: 0.14343033731
# Epoch: 174, Training Loss: 0.143436482549
# Epoch: 175, Training Loss: 0.143442617357
# Epoch: 176, Training Loss: 0.143448698521
# Epoch: 177, Training Loss: 0.143454673886
# Epoch: 178, Training Loss: 0.143460465968
# Epoch: 179, Training Loss: 0.143466004729
# Epoch: 180, Training Loss: 0.143471163511
# Epoch: 181, Training Loss: 0.143475843966
# Epoch: 182, Training Loss: 0.143479864299
# Epoch: 183, Training Loss: 0.143483005464
# Epoch: 184, Training Loss: 0.14348500967
# Epoch: 185, Training Loss: 0.14348552525
# Epoch: 186, Training Loss: 0.143484085798
# Epoch: 187, Training Loss: 0.143480107188
# Epoch: 188, Training Loss: 0.143472804129
# Epoch: 189, Training Loss: 0.14346114099
# Epoch: 190, Training Loss: 0.143443740904
# Epoch: 191, Training Loss: 0.143418772519
# Epoch: 192, Training Loss: 0.143383856118
# Epoch: 193, Training Loss: 0.143335855007
# Epoch: 194, Training Loss: 0.143270881474
# Epoch: 195, Training Loss: 0.143184307218
# Epoch: 196, Training Loss: 0.143071167171
# Epoch: 197, Training Loss: 0.142927098274
# Epoch: 198, Training Loss: 0.142749810219
# Epoch: 199, Training Loss: 0.142540761828
# Epoch: 200, Training Loss: 0.142306087911
# Epoch: 201, Training Loss: 0.142055727541
# Epoch: 202, Training Loss: 0.141800640523
# Epoch: 203, Training Loss: 0.141549612582
# Epoch: 204, Training Loss: 0.14130705297
# Epoch: 205, Training Loss: 0.141072751582
# Epoch: 206, Training Loss: 0.140843120217
# Epoch: 207, Training Loss: 0.140612860024
# Epoch: 208, Training Loss: 0.14037642777
# Epoch: 209, Training Loss: 0.140128929913
# Epoch: 210, Training Loss: 0.139866614342
# Epoch: 211, Training Loss: 0.139586949348
# Epoch: 212, Training Loss: 0.139288619161
# Epoch: 213, Training Loss: 0.138971427083
# Epoch: 214, Training Loss: 0.138636080921
# Epoch: 215, Training Loss: 0.138284122944
# Epoch: 216, Training Loss: 0.137917593122
# Epoch: 217, Training Loss: 0.137538841367
# Epoch: 218, Training Loss: 0.137150259316
# Epoch: 219, Training Loss: 0.13675404191
# Epoch: 220, Training Loss: 0.136352081597
# Epoch: 221, Training Loss: 0.135945743322
# Epoch: 222, Training Loss: 0.135535763204
# Epoch: 223, Training Loss: 0.135122096539
# Epoch: 224, Training Loss: 0.134703910351
# Epoch: 225, Training Loss: 0.134279638529
# Epoch: 226, Training Loss: 0.13384718895
# Epoch: 227, Training Loss: 0.133404140174
# Epoch: 228, Training Loss: 0.132947942615
# Epoch: 229, Training Loss: 0.132475975156
# Epoch: 230, Training Loss: 0.131985625625
# Epoch: 231, Training Loss: 0.131474255025
# Epoch: 232, Training Loss: 0.130939094722
# Epoch: 233, Training Loss: 0.130376921594
# Epoch: 234, Training Loss: 0.129783642292
# Epoch: 235, Training Loss: 0.129153523594
# Epoch: 236, Training Loss: 0.128478306532
# Epoch: 237, Training Loss: 0.127745979279
# Epoch: 238, Training Loss: 0.126939066499
# Epoch: 239, Training Loss: 0.126032102108
# Epoch: 240, Training Loss: 0.124987683445
# Epoch: 241, Training Loss: 0.12375048548
# Epoch: 242, Training Loss: 0.122240126878
# Epoch: 243, Training Loss: 0.12035273239
# Epoch: 244, Training Loss: 0.118007077277
# Epoch: 245, Training Loss: 0.115274561942
# Epoch: 246, Training Loss: 0.112378967553
# Epoch: 247, Training Loss: 0.109232626855
# Epoch: 248, Training Loss: 0.105578627437
# Epoch: 249, Training Loss: 0.101832643151
# Epoch: 250, Training Loss: 0.0980112276971
# Epoch: 251, Training Loss: 0.094590870291
# Epoch: 252, Training Loss: 0.0917170971632
# Epoch: 253, Training Loss: 0.0893311470747
# Epoch: 254, Training Loss: 0.0872407972813
# Epoch: 255, Training Loss: 0.0852067731321
# Epoch: 256, Training Loss: 0.0831581391394
# Epoch: 257, Training Loss: 0.0812464907765
# Epoch: 258, Training Loss: 0.0796542607248
# Epoch: 259, Training Loss: 0.0784062497318
# Epoch: 260, Training Loss: 0.0773932307959
# Epoch: 261, Training Loss: 0.0764971777797
# Epoch: 262, Training Loss: 0.0756638638675
# Epoch: 263, Training Loss: 0.0748956851661
# Epoch: 264, Training Loss: 0.0742115199566
# Epoch: 265, Training Loss: 0.0736169502139
# Epoch: 266, Training Loss: 0.0730993822217
# Epoch: 267, Training Loss: 0.0726390607655
# Epoch: 268, Training Loss: 0.0722198762
# Epoch: 269, Training Loss: 0.0718328461051
# Epoch: 270, Training Loss: 0.071474121511
# Epoch: 271, Training Loss: 0.0711413696408
# Epoch: 272, Training Loss: 0.070831938833
# Epoch: 273, Training Loss: 0.0705426387489
# Epoch: 274, Training Loss: 0.0702701501548
# Epoch: 275, Training Loss: 0.0700115777552
# Epoch: 276, Training Loss: 0.0697646357119
# Epoch: 277, Training Loss: 0.0695276029408
# Epoch: 278, Training Loss: 0.0692991793156
# Epoch: 279, Training Loss: 0.0690782129765
# Epoch: 280, Training Loss: 0.0688637241721
# Epoch: 281, Training Loss: 0.0686548240483
# Epoch: 282, Training Loss: 0.0684506766498
# Epoch: 283, Training Loss: 0.068250567466
# Epoch: 284, Training Loss: 0.0680538542569
# Epoch: 285, Training Loss: 0.0678599372506
# Epoch: 286, Training Loss: 0.0676684133708
# Epoch: 287, Training Loss: 0.0674788400531
# Epoch: 288, Training Loss: 0.0672908343375
# Epoch: 289, Training Loss: 0.0671041898429
# Epoch: 290, Training Loss: 0.0669187456369
# Epoch: 291, Training Loss: 0.0667342029512
# Epoch: 292, Training Loss: 0.066550463438
# Epoch: 293, Training Loss: 0.0663674905896
# Epoch: 294, Training Loss: 0.0661851927638
# Epoch: 295, Training Loss: 0.0660034548491
# Epoch: 296, Training Loss: 0.065822225064
# Epoch: 297, Training Loss: 0.065641522035
# Epoch: 298, Training Loss: 0.0654613077641
# Epoch: 299, Training Loss: 0.0652815874666
# Epoch: 300, Training Loss: 0.065102237463
# Epoch: 301, Training Loss: 0.0649233769625
# Epoch: 302, Training Loss: 0.0647449765354
# Epoch: 303, Training Loss: 0.0645670421422
# Epoch: 304, Training Loss: 0.0643895715475
# Epoch: 305, Training Loss: 0.0642125226557
# Epoch: 306, Training Loss: 0.0640359178185
# Epoch: 307, Training Loss: 0.0638597376645
# Epoch: 308, Training Loss: 0.0636840566993
# Epoch: 309, Training Loss: 0.0635089173913
# Epoch: 310, Training Loss: 0.0633342254907
# Epoch: 311, Training Loss: 0.0631600502878
# Epoch: 312, Training Loss: 0.0629863414913
# Epoch: 313, Training Loss: 0.0628130536526
# Epoch: 314, Training Loss: 0.062640254572
# Epoch: 315, Training Loss: 0.0624679259956
# Epoch: 316, Training Loss: 0.0622959692031
# Epoch: 317, Training Loss: 0.0621243815869
# Epoch: 318, Training Loss: 0.0619530882686
# Epoch: 319, Training Loss: 0.0617820195854
# Epoch: 320, Training Loss: 0.0616111468524
# Epoch: 321, Training Loss: 0.0614403855056
# Epoch: 322, Training Loss: 0.0612696520984
# Epoch: 323, Training Loss: 0.0610988937318
# Epoch: 324, Training Loss: 0.0609280712903
# Epoch: 325, Training Loss: 0.0607570808381
# Epoch: 326, Training Loss: 0.060585802421
# Epoch: 327, Training Loss: 0.0604142475873
# Epoch: 328, Training Loss: 0.0602422844619
# Epoch: 329, Training Loss: 0.0600699432194
# Epoch: 330, Training Loss: 0.0598971184343
# Epoch: 331, Training Loss: 0.0597237467766
# Epoch: 332, Training Loss: 0.0595497243106
# Epoch: 333, Training Loss: 0.0593750815839
# Epoch: 334, Training Loss: 0.0591998327523
# Epoch: 335, Training Loss: 0.05902389884
# Epoch: 336, Training Loss: 0.0588472746313
# Epoch: 337, Training Loss: 0.0586699899286
# Epoch: 338, Training Loss: 0.0584921311587
# Epoch: 339, Training Loss: 0.0583137508482
# Epoch: 340, Training Loss: 0.0581350382417
# Epoch: 341, Training Loss: 0.0579561602324
# Epoch: 342, Training Loss: 0.0577773805708
# Epoch: 343, Training Loss: 0.0575992278755
# Epoch: 344, Training Loss: 0.0574220232666
# Epoch: 345, Training Loss: 0.0572465013713
# Epoch: 346, Training Loss: 0.0570732846856
# Epoch: 347, Training Loss: 0.0569031398743
# Epoch: 348, Training Loss: 0.0567368481308
# Epoch: 349, Training Loss: 0.0565750189126

# %%
plt.figure()
plt.plot(evalLoss[:], 'b')
plt.plot(evalLoss[:], 'or')
plt.xlabel('epochs')
plt.ylabel('error')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'error')

# %% [markdown]
# # Plot Predictions Before Training

# %%
plot = K3D()
plot += K3D.points ( np.hstack( ( batchInputs, targetValues*zScaling) ), color=0xFF0000, point_size = .1, shader = 'flat' )
plot += K3D.points ( np.hstack( ( batchInputs, currentNN[0]*zScaling) ), color=0xEE00EE, point_size = .3, shader = 'flat' )        
plot += K3D.surface ( z*zScaling, color=0x0000FF, xmin=np.min(xRange), xmax=np.max(xRange), ymin=np.min(yRange), ymax=np.max(yRange))
plot.display()
# Out:
# K3D(parameters={'backgroundColor': 16777215, 'height': 512, 'antialias': True})

# %% [markdown]
# # Plot Predictions Midway Through Training

# %%
plot = K3D()
plot += K3D.points ( np.hstack( ( batchInputs, targetValues*zScaling) ), color=0xFF0000, point_size = .1, shader = 'flat' )
plot += K3D.points ( np.hstack( ( batchInputs, currentNN[int(plotCount/2)]*zScaling) ), color=0xEE00EE, point_size = .3, shader = 'flat' )        
plot += K3D.surface ( z*zScaling, color=0x0000FF, xmin=np.min(xRange), xmax=np.max(xRange), ymin=np.min(yRange), ymax=np.max(yRange))
plot.display()
# Out:
# K3D(parameters={'backgroundColor': 16777215, 'height': 512, 'antialias': True})

# %% [markdown]
# # Plot Predictions at End of Training

# %%
plot = K3D()
plot += K3D.points ( np.hstack( ( batchInputs, targetValues*zScaling) ), color=0xFF0000, point_size = .1, shader = 'flat' )
plot += K3D.points ( np.hstack( ( batchInputs, currentNN[int(plotCount-1)]*zScaling) ), color=0xEE00EE, point_size = .3, shader = 'flat' )        
plot += K3D.surface ( z*zScaling, color=0x0000FF, xmin=np.min(xRange), xmax=np.max(xRange), ymin=np.min(yRange), ymax=np.max(yRange))
plot.display()
# Out:
# K3D(parameters={'backgroundColor': 16777215, 'height': 512, 'antialias': True})

# %% [markdown]
# ## thanks!
